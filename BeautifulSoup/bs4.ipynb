# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\bapti\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bapti\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
#import 
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.sfr.fr/")

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="fr" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=5,user-scalable=yes" name="viewport"/>
# <link href="https://static.s-sfr.fr/media/icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://static.s-sfr.fr" rel="preconnect"/>
# <link as="font" crossorigin="anonymous" href="//static.s-sfr.fr/assets/fonts/Poppins-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="//static.s-sfr.fr/assets/fonts/Poppins-Bold.woff2" rel="preload" type="font/woff2"/>
# <link href="//static.s-sfr.fr/resources/css/base-1.0.0.css" rel="prefetch stylesheet" type="text/css"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>SFR | Forfait Mobile, Téléphone, Internet Fibre et ADSL, TV</title><meta content="Découvrez les offres Mobile et Internet SFR : forfaits mobiles et smartphones, internet très haut débit Fibre, ADSL et box 4G+, et l'expérience TV. Bienvenue sur sfr.fr !" name="Description"/>
# <script>_is_authenticated=false;
# _stats_timestamp="1711365213145";
# sfrIstConfig=djangoUtils={};
# sfrIstConfig.context='static.s-sfr.fr';
# </script><link href="https://www.sfr.fr/" rel="canonical"/>
# <meta content="SFR | Forfait Mobile, Téléphone, Internet Fibre et ADSL, TV" property="og:title"/>
# <meta content="Découvrez les offres Mobile et Internet SFR : forfaits mobiles et smartphones, internet très haut débit Fibre, ADSL et box 4G+, et l'expérience TV. Bienvenue sur sfr.fr !" property="og:description"/>
# <meta content="https://static.s-sfr.fr/media/icon-192x192.png" property="og:image"/>
# <meta content="website" property="og:type"/><meta content="https://www.sfr.fr/" property="og:url"/>
# <meta content="SFR" property="og:site_name"/>
# <meta content="100002952604097" property="fb:admins"/><meta content="summary" name="twitter:card"/>
# <meta content="https://twitter.com/SFR" name="twitter:site"/>
# <meta content="SFR | Forfait Mobile, Téléphone, Internet Fibre et ADSL, TV" name="twitter:title"/>
# <meta content="https://www.sfr.fr/" name="twitter:url"/>
# <meta content="Découvrez les offres Mobile et Internet SFR : forfaits mobiles et smartphones, internet très haut débit Fibre, ADSL et box 4G+, et l'expérience TV. Bienvenue sur sfr.fr !" name="twitter:description"/>
# <script type="application/ld+json">{"@context": "https://schema.org","@type": "Organization", "url": "https://www.sfr.fr/", "logo": "https://static.s-sfr.fr/media/icon-192x192.png" }</script>
# <script type="application/ld+json">{"@context": "https://schema.org","@type": "WebSite","name": "SFR","url": "https://www.sfr.fr/"}</script>
# <link as="image" href="https://static.s-sfr.fr/assets/backgrounds/accordeon/mob_brume-violette_bg_acc.webp" rel="preload"/>
# <link as="image" href="https://static.s-sfr.fr/media/mobile/MEA/accordeon/mob_iphone-15-pro_acc.webp" rel="preload"/>
# <style>
#     main { display: flex; flex-direction: column; background: #f2f2f2; }
# #Acc5 { order:1; }
# h1 { order: 2; font-family: 'SFR-Bold'; font-size: 32px; line-height: 36px; margin: 40px auto 24px; max-width: 1280px; width: calc(100% - 64px); text-align: left;}
# h2 { text-align: left; }
# #Pilier { order:3; }
# #Choose { order: 4; }
# #Best { order:5; }
# #Rea { order:6; }
# #News { order:7; }
# #eTav { order:8; }
# #SEO { order:9; }
# #Mentions { order:10; }
# #Pilier { padding: 0; display: none; }
# #TT { display: none; }
# #eTsNL { order:9; }
#
# #Acc5 { width: 100%; height: 460px; position: relative; overflow: hidden; }
# #Acc5 .heroes { position: relative; height: 100%; }
# #Acc5 .hero { position: relative; height: 100%; display:block; background-repeat: no-repeat; animation: fadein 1s ease-out; }
# #Acc5 .hero:before { content: ''; height: 296px; position: absolute; bottom: 0; left: 0; right: 0; width: 100%; background: rgba(226, 0, 0, 0.8); background-image: linear-gradient(360deg, var(--clr-sfr) 70%, rgba(97, 91, 91, 0) 95%); box-shadow: 0px 0 30px 40px rgb(0 0 0 / 30%); }
# #Acc5 .hero>.illu { object-fit: cover; display: flex; width: 100%; height: 100%; z-index: -1;}
# #Acc5 .hero>.c { position: absolute; left: 40px; right: 40px; bottom: 0; margin: auto; max-width: 1280px; height: 296px; display: flex; justify-content: space-between; }
# #Acc5 .hero>.c>div { display: inline-block; vertical-align: top; }
# #Acc5 .hero>.c>.L { width: 290px; margin: -26px 40px 0 0; }
# #Acc5 .hero>.c>.L strong { display: block; font-family: 'SFR-Bold'; font-size: 32px; line-height: 48px; color: #fff; margin: 0 0 16px 0; font-weight:100;}
# #Acc5 .hero>.c>.L p { display: block; font-family: 'SFR-Regular'; font-size: 16px; line-height: 24px; color: #fff; }
# #Acc5 .hero>.c>.L .stars { margin: 16px 0 0 0; }
# #Acc5 .hero>.c>.L .stars>i{ width: 90px; height: 16px; background: url(//static.s-sfr.fr/media/stars-12-grey.svg) no-repeat 0 0; background-size: cover; display: inline-block; vertical-align: middle; }
# #Acc5 .hero>.c>.L .stars>i mark { height: 16px; background: url(//static.s-sfr.fr/media/stars-12-yellow.svg) no-repeat 0 0; background-size: cover; display: block; filter: invert(75%) sepia(86%) saturate(1646%) hue-rotate(26deg) brightness(150%) contrast(107%); }
# #Acc5 .hero>.c>.L .stars>span{ font-size: 12px; color: #fff; line-height: 18px; display: inline-block;vertical-align: middle; margin: 0 0 0 8px; }
# #Acc5 .hero>.c>.M { width: 620px; }
# #Acc5 .hero>.c>.M .illu.mob { display:none }
# #Acc5 .hero>.c>.R { width: 290px; margin: 0 0 118px 0; align-self: flex-end; }
# #Acc5 .hero>.c>.R .sticker { background: var(--clr-yellow); font-family: 'SFR-Bold'; color: var(--clr-black); margin: -20px 0 0 0; font-size: 12px; padding: 0 8px; border-radius: 4px; display: table;}
# #Acc5 .hero>.c>.R .sticker + .price { margin-top: 22px;  }
# #Acc5 .hero>.c>.R .apd { font-size: 14px; line-height: 22px; font-family: 'SFR-Bold'; display: block; color: #fff;  }
# #Acc5 .hero>.c>.R .apd + .price { margin: 0; }
# #Acc5 .hero>.c>.R .apd + .info { margin: 0 0 8px 0; }
# #Acc5 .hero>.c>.R .price { margin: 20px 0 0 0; justify-content: left; }
# #Acc5 .hero>.c>.R .price .L { font-size: 60px; line-height: 48px; color: #fff; }
# #Acc5 .hero>.c>.R .price .R { font-size: 16px; line-height: 24px; color: #fff;}
# #Acc5 .hero>.c>.R .price + a { margin: 16px 0 0 0; }
#
# #Acc5 .hero>.c>.R>.info { font-family: 'SFR-Bold'; color: #fff; font-size: 12px; line-height: 18px; margin: 8px 0;}
# #Acc5 .hero>.c>.R>a { display: table; width: auto; position: static; }
# #Acc5 .hero>.c>.R>a:after { content: ''; position: absolute; left: -640px; right: -640px; top: -164px; width: auto; height: 460px; }
# #Acc5 .hero>.c>.B { display: block; position: absolute; width: fit-content; width:100%; bottom: 80px; height: 18px; }
# #Acc5 .hero>.c>.B>span{ position: absolute; top: 0; right: 0; color: #fff; font-size: 12px; line-height: 18px; display: table; width: calc(100% - 70px);}
# #Acc5 .hero>.c>.B>span:not(.bubble) { text-align: right; }
# #Acc5 .hero>.c>.B>input { display: none; }
# #Acc5 .hero>.c>.B .bubble{ display: none; }
#
# #Acc5 .hero>.c>.B span.das{ left: 0; cursor: pointer; color: #fff; font-size: 12px; line-height: 18px; display: table; position: relative; width:fit-content;}
# #Acc5 .hero>.c>.B span.das:after { content: ''; background-image: url(https://static.s-sfr.fr/assets/pictos/aide_plein_40_blanc.svg); width: 14px; height: 14px; display: block; background-size:contain; background-repeat:no-repeat; position: absolute; top: 1px; left: 28px; }
# #Acc5 .hero>.c>.B span.das:hover + .bubble {display:block; cursor: auto; width: 150px; box-shadow: 0 2px 4px 0 rgb(0 0 0 / 10%); border-radius: 4px; color: #fff; font-family: 'SFR-Regular'; background-color: var(--clr-black); font-size: 10px; padding: 3px; position: absolute; z-index: 9; transition: opacity 0.3s; bottom: 25px; }
# #Acc5 .hero>.c>.B span.das + .bubble:after {content: ""; position: absolute; bottom: -14px; left: 8px; margin-top: -5px; border-width: 7px; border-style: solid; border-color: var(--clr-black) transparent transparent transparent;}
# #Acc5 .hero>.c>.B span.das + .bubble + span { text-align: right; }
#
# #Acc5 .capsules { max-width: 1280px; width: calc(100% - 80px); margin: -70px auto 0 auto; position: relative; display: flex; justify-content: space-around; gap: 0 40px; }
# #Acc5 .cap { display: inline-block; vertical-align: middle; width: 288px; padding: 0 8px 0 0; background: rgba(255, 255, 255, 0.2);max-width: calc(100% / 4 - 15px); width: 288px; font-family: 'SFR-Regular'; color: #fff; border-radius: 8px; font-size: 14px; line-height: 18px; cursor: pointer;  transition: background .3s ease-out; }
# #Acc5 .cap>div { width: 52px; height: 52px; display: inline-block; vertical-align: middle; margin: 0 14px 0 0; }
# #Acc5 .cap>div>.vign { height: 100%; }
# #Acc5 .cap>span { display:inline-block; vertical-align: middle; width: calc(100% - 70px); }
# #Acc5 .cap:hover { background: rgba(24, 24, 24, 0.2);}
# #Acc5 .cap.s { background: rgba(24, 24, 24, 0.2); font-family: 'SFR-Bold';}
# #Acc5 .cap:last-child { margin: 0; }
# #Acc5 .hero[hidden] { background:none; background-image:none; display:none; }
#
# .arrow {padding-right:12px;}
# .arrow:after {content: ''; position: absolute;width: 7px;height: 7px;background-color: transparent;border: 2px solid;right: 0;transform: rotate(45deg);top: 0;bottom: 0;margin: auto;border-left: 0;border-bottom: 0;transition: all .2s cubic-bezier(.4,0,.2,1);}
# .arrow:hover:after {right: -5px;}
# a .arrow {position: relative; display: inline-block; vertical-align: middle; height: 8px; width: 8px; right: -8px;}
# a .arrow:after {content: ''; position: absolute;width: 8px;height: 8px;background-color: transparent;border: 2px solid;right: 0;transform: rotate(45deg);top: 0;bottom: 0;margin: auto;border-left: 0;border-bottom: 0;}
# a:hover .arrow {right: -12px; transition: all .2s cubic-bezier(.4,0,.2,1);}
#
# #Choose { background: #fff; box-shadow: 0px 8px 16px rgba(24, 24, 24, 0.02); border-radius: 12px; max-width: 1280px; margin: 0 auto 40px auto; width: calc(100% - 64px); padding: 24px 24px 90px 24px; display: flex; gap: 22px; flex-wrap: wrap; position: relative; justify-content: space-evenly;  }
# #Choose .c { text-align: center; width: 225px; }
# #Choose .c>img{ height: 64px; margin: 0 0 16px 0; }
# #Choose .c p{ font-family: 'SFR-Bold'; font-size: 14px; margin: 0 0 16px 0; }
# #Choose .c a.link{ text-decoration: none; }
# #Choose .btn4 { width: fit-content; margin: 0 auto; position: absolute; bottom: 24px; left: 0; right: 0; }
#
# #Pilier {text-align: center; padding-bottom: 18px;}
# #Pilier h1 {font-family: 'SFR-Bold'; font-size: 32px; line-height: 36px;margin: 32px auto 40px;}
# #Pilier .z {display: inline-block; vertical-align: middle; width: 720px; text-align: left; margin-bottom: 25px;}
# #Pilier .p {position: relative; display: inline-block; text-align: left; vertical-align: top; margin: 0 1% 0 0;}
# #Pilier .p:last-child {border:none;}
# #Pilier .p .si {display: inline-block; vertical-align: middle; margin: 0px 8px 0 0; }
# #Pilier .p .si + div {display: inline-block; vertical-align: middle;}
# #Pilier .p a {position: relative; display: inline-block; vertical-align: middle; font-family: 'SFR-Bold'; font-size: 14px; text-decoration: none; color: var(--clr-sfr2); line-height: 16px; margin-right: 15px;}
# #Pilier .p a:before {content: ''; position: absolute; width: calc(100% + 92px); height: 70px; top: -50px; left: -63px;}
# #Pilier .p a.m {display: none;}
# #Pilier .p p {margin: 0 0 10px 0; line-height: 18px; width: 190px; font-family: 'SFR-Regular'; font-size: 14px; color: var(--clr-black);}
# #Pilier .m {display: none;}
#
# @keyframes ltr2 {0% {right:-12px;} 50% {right: -20px;} 95% {right: -9px;} 100% {right: -12px;}}
# .tooltip {cursor: pointer; position: absolute; bottom: 45px; right: 20px;z-index:2;}
# #Good { order: 5; position: sticky; padding: 40px 0 0 0; text-align: center; background-color: var(--clr-bg); width: calc(100% - 64px); max-width: 1280px; margin: 0 auto; }
# #Good .wrap {/*width: calc(100% - 64px);max-width: 1280px;*/margin: 24px auto 0 auto;display: grid; grid-template-columns: repeat(3, 1fr); column-gap: 40px; }
# #Good .cbp { background: #fff; padding: 24px; margin: 0 0 40px 0; border-radius: 8px; position: relative; text-align: left; display: grid; grid-row: span 7; grid-template-rows: subgrid; }
# #Good .cbp:hover>img{ transform: scale(1.1); }
# #Good .cbp>img { height: 198px; max-width: 100%; margin: 0 auto 34px auto; display: block; object-fit: contain; transition: 0.5s ease-out transform;}
# #Good .cbp>img + .tooltip + a { margin: 78px 0 8px 0;}
# #Good .cbp>img + a { margin: 78px 0 8px 0;}
# #Good .cbp .tooltip { top: 222px; right: 24px; z-index:2; bottom: auto;}
# #Good .cbp .tooltip .das {position: relative;font-family: 'SFR-Regular';font-size: 12px;line-height:12px; padding: 0 17px 0 0;}
# #Good .cbp .tooltip .das:after {content: "";position: absolute; bottom: -1px; right: 0; width: 15px; height: 15px;background: url(//static.s-sfr.fr/assets/pictos/aide_plein_40_noir.svg);background-repeat:no-repeat;background-size:cover; }
# #Good .cbp .tooltip .tooltiptext { visibility: hidden; cursor: auto; width: 130px; box-shadow: 0 2px 4px 0 rgb(0 0 0 / 10%); border-radius: 4px; color: #fff; font-family: 'SFR-Regular'; background-color: var(--clr-black); font-size: 10px; padding: 8px; position: absolute; z-index: 9; right: -20px; top: auto; bottom: 23px;  transition: opacity 0.3s;}
# #Good .cbp .tooltip .tooltiptext::after {content: ""; position: absolute; bottom: -12px; left: 73%; margin-top: -5px; border-width: 7px; border-style: solid; border-color: var(--clr-black) transparent transparent transparent;}
# #Good .cbp .tooltip:hover .tooltiptext { display: block; visibility: visible; opacity: 1; }
# #Good .cbp .tooltip .das:focus ~ .tooltiptext { display: block; visibility: visible; opacity: 1; }
#
# #Good .cbp .stickers { text-align: left; margin: 0 0 8px 0;}
# #Good .cbp .stickers>span{ border-radius: 4px; padding: 2px 8px; font-size: 14px; font-family: 'SFR-Bold'; line-height: normal; display: inline-block; margin: 0 8px 8px 0;}
# #Good .cbp .stickers>span strong{ font-family: 'SFR-Bold'; }
#
# #Good .cbp>a.t { display:block; font-family: 'SFR-Bold'; font-size: 24px; line-height: normal; margin: 0 0 8px 0; text-decoration: none; color: var(--clr-black);}
# #Good .cbp>a.t:after { content: '';  position: absolute; width: 100%; height: 100%; left: 0; top: 0;}
# #Good .cbp a+p { display:block; font-family: 'SFR-Regular'; font-size: 14px; line-height: normal; margin:0 0 16px 0;}
# #Good .cbp .M { height: 62px; margin: 0 0 16px 0;}
# #Good .cbp .avis { position:relative; margin: 0 0 16px 0; }
# #Good .cbp .avis span { font-size: 12px; font-family: 'SFR-Bold'; display: inline-block; vertical-align: middle; margin: 0 4px 0 0;}
# #Good .cbp .avis>span.nbr { font-size:12px; font-family: 'SFR-Regular'; display:inline-block; z-index: 5; position: absolute; top: 5px; margin: 0 0 0 5px; color:var(--clr-black);}
# #Good .cbp .avis>img{ height: 16px; width: 16px; filter: invert(84%) sepia(19%) saturate(5971%) hue-rotate(0deg) brightness(105%) contrast(103%); display: inline-block; vertical-align: middle; }
# #Good .cbp .avis>svg{ display: inline-block; vertical-align: middle; }
# #Good .cbp .avis>img.emp{ height: 18px; width: 18px; margin: 0 0 0 -1px; }
# #Good .cbp .taddp {display: block; font-size: 14px;}
# #Good .cbp .B { font-size: 14px; }
# #Good .cbp .B .taddp + .price { margin: 8px 0; }
# #Good .cbp .B .price { width: fit-content; margin: 26px 0 8px 0;}
# #Good .cbp span{ display: block;}
# #Good .cbp .B span:last-child{ margin: 0; }
# #Good .cbp .B>span.s1{ margin: 50px 0 0 0; }
# #Good .cbp .B>p{ margin: 0 0 8px 0; display: block; height: 42px;}
# #Good .cbp a.link {text-align: center; width: max-content; text-decoration:none;margin: 24px auto 0 auto;}
#
# @keyframes fadein {from {opacity: 0.5;} to {opacity: 1;}}
#
# #News {position: relative; max-width: 1280px; width:calc(100% - 64px); margin: 40px auto; background-color: var(--clr-bg); text-align: center; /*padding: 40px 0;*/}
# #News h2 {font-family: 'SFR-Bold'; color: var(--clr-black); text-align: left; text-transform: unset; display: block; margin: 0 auto 24px;}
# #News .card { box-shadow: 0 0 24px 4px rgba(0, 0, 0, 0.06); border-radius: 8px; box-sizing: border-box; }
# #News .card a {text-decoration: none;}
# #News .card .T {position: relative; height: 192px; width: 100%; background-size: cover; background-position: center center; border-radius: 8px 8px 0 0; overflow: hidden;}
# #News .card .T span {position: absolute; color: #fff; font-family: 'SFR-Bold'; background-color: var(--clr-black); font-size: 10px; border-radius: 4px; padding: 5px 8px; top: 12px; left: 12px;}
# #News .card .T .illu {width: 100%; border-radius: 8px 8px 0 0;}
# #News .card .T .illu>img {object-fit: cover;}
# #News .card .T .illu.mob { display: none; }
# #News .card .B {height: calc(320px - 192px); width: 100%; padding: 16px 24px; text-align: left; box-sizing: border-box; white-space: normal; background-color:#fff; border-radius: 0 0 8px 8px;}
# #News .card .B .date {font-family: 'SFR-Regular';font-size: 12px;line-height: 16px;color: var(--clr-black);display: block;margin-bottom: 8px;}
# #News .card .B .titre {font-family: 'SFR-Bold';font-size: 16px;line-height: 20px;color: var(--clr-black);margin-bottom: 8px;}
# #News .card .B p {font-family: 'SFR-Regular';font-size: 12px;line-height: 14px;color: var(--clr-black);margin: 8px 0 0;}
# #News>a {position:relative;display: table; margin: 40px auto 0 auto;text-decoration: none;width: fit-content;}
# #News>a:hover { box-shadow: 0 4px 12px rgb(24 24 24 / 32%);}
# #News>a>.arrow { display:none; }
# #News .carousel-preview {display: none;}
# #News #carousel-actu { margin: 0 auto; display: flex; justify-content: center; gap: 40px; }
# #News #carousel-actu > div > div {scroll-snap-type: x mandatory;}
# #News #actu-dots {display: none;}
# body #eTav>ul>li {color: #595959;}
#
# @media all and (max-width: 1100px) {
#     h1 { background: #fff; padding: 16px; margin: 0; width: auto; font-size: 24px; }
#     #Pilier { display: block; background: #fff; overflow:hidden;}
#     #TT { display: flex; order: 7; margin: 16px auto 40px auto; width: calc(100% - 32px); max-width: 1280px; }
#     #Choose { flex-direction: column; order: 7; gap: 40px; width: calc(100% - 32px); margin: 0 auto 24px auto; }
#     #Choose .c { max-width: none; width: auto; }
#     #Choose .c>img { height: 60px; margin: 0 0 8px 0; }
#     #Choose .c p { margin: 0 0 8px 0; }
#
#     #Acc5 { height: 560px; }
#     #Acc5 .hero:before { height: 448px; }
#     #Acc5 .hero>.c { display: block; height: 448px; left: 16px; right: 16px; display: flex; justify-content: space-around; gap: unset; }
#     #Acc5 .hero>.c>.L { width: 100%; display: block; text-align: center; margin: -26px 0 0 0; position: absolute; }
#     #Acc5 .hero>.c>.L strong { margin: 0 0 0 0; }
#     #Acc5 .hero>.c>.L .stars { margin: 8px 0 0 0; }
#     #Acc5 .hero>.c>.M { max-width: none; width: auto; text-align: right; text-align: center; }
#     #Acc5 .hero>.c>.M .illu { display:none }
#     #Acc5 .hero>.c>.M .illu.mob { display:block }
#     #Acc5 .hero>.c>.R { max-width: none; width: auto; margin: 0 0 178px 0; }
#     #Acc5 .hero>.c>.R>a:after { height: 612px; }
#     #Acc5 .hero>.c>.B { bottom: 146px; }
#     #Acc5 .capsules { width: 100%; max-width: 1100px; margin: -136px auto 0 auto; flex-wrap: wrap; flex-direction: row; gap: 16px; justify-content: space-evenly; padding: 0 16px 16px 16px;}
#     #Acc5 .cap { max-width: none; width: calc(50% - 8px); height: 52px; font-size: 12px; line-height: 18px; padding: 0; }
#     #Acc5 .cap>div { margin: 0 8px 0 0; }
#     #Acc5 .cap>span { width: calc(100% - 70px); }
#
#     #Pilier h1 {font-size: 24px;}
#     #Pilier .p {text-align: center; display: block; border-bottom: 1px solid #d8d8d8; padding: 16px 0; border-right: none; margin: 0 32px;}
#     #Pilier .p svg.si {display: none;}
#     #Pilier .p div>p {display: none;}
#     #Pilier .p .si + div {margin-left: 32px;}
#     #Pilier .p .m {position: relative;display: block;text-align: left; margin-right: 2px}
#     #Pilier .p .m svg {display:inline-block;vertical-align: middle;}
#     #Pilier .p .m a{margin-right:0;width: calc(100% - 40px);color: var(--clr-black);}
#     #Pilier .p:last-child { color: var(--clr-sfr2); }
#     #Pilier .p:last-child .m svg{ filter: invert(13%) sepia(79%) saturate(6072%) hue-rotate(348deg) brightness(86%) contrast(98%); }
#     #Pilier .p:last-child .m a{ color: var(--clr-sfr2);}
#     #Pilier .p>div:not(.m) {display: none;}
#     #Pilier .p a:before {content: '';position: absolute;width: 100vw;height: calc(100% + 32px);top: -16px;left: -44px;}
#
#     #Good { width: calc(100% - 32px); }
#     #Good .wrap { grid-template-columns: repeat(2, 1fr); gap: 0 16px; }
#     #Good .cbp { padding: 16px; margin: 0 0 16px 0; }
#     #Good .cbp>img { height: 185px; }
#     #Good .cbp:hover>img{ transform: none; }
#     #Good .cbp .tooltip { top: 205px; }
#     #Good .cbp>a.t { font-size: 16px; line-height: normal;}
#
#     #News {position: relative; padding: 0; width: calc(100% - 32px); }
#     #News h2 {font-size: 24px; line-height: 28px; color: var(--clr-black); margin: 0 0 40px 0;}
#     #News .card { height: 292px; margin: 0 0 16px 0; display:block;vertical-align: top;}
#     #News .card .T {height: 162px;}
#     #News .card .T .illu { display: none; }
#     #News .card .T .illu.mob { display: block; }
#     #News .card .T span {}
#     #News .card .B {height: calc(292px - 162px); box-sizing: border-box;}
#     #News .card .B .titre {font-size: 14px;line-height: 18px;}
#     #News a {margin: 0 auto 24px auto;}
#     #News #carousel-actu { display: block; max-width: 100%; width: 100%; margin: 0; gap: 16px;}
# }
# @media all and (max-width: 768px) {
#     .arrow:after {width:6px;height:6px;}
#     #Acc5 .hero>.c{ gap: 16px; }
#     #Acc5 .hero>.c>.L { margin: -18px 0 0 0; }
#     #Acc5 .hero>.c>.L strong { font-size: 24px; line-height: 36px;  margin: 0;}
#     #Acc5 .hero>.c>.L p { font-size: 14px; line-height: 22px; }
#
#     #Pilier {padding-bottom: 8px;}
#     #Pilier .p {margin:0 16px;}
#     #Pilier h1 {font-size: 20px;margin:24px auto 8px;}
#         #Good .wrap { grid-template-columns: repeat(1, 1fr); width: auto; }
#         #Good .cbp { display: block; width: 100%; min-width: 325px; margin: 0 auto 16px auto; }
#         #Good .cbp a.link { display: block; }
#
#     #News h2 {font-size: 20px;}
# }
#     #IFS {height: 2px; width: 2px; position: fixed; top: 99vh; left: 0;}
#
#
#
#    #MEA1-iphone15-mobile{ background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/desk_brume-violette_bg_acc.webp); background-size: cover; background-position: left;}
#
#     #MEA2-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/desk_famille_canape_bg_acc_v2.webp); background-size: cover; background-position: center top;}
#
#     #MEA3-honormagc6pro-mobile {background: linear-gradient(180deg, #F2F2F2 72.37%, #545454 100%);}
#     #MEA3-honormagc6pro-mobile:before {display: none;}
#     #MEA3-honormagc6pro-mobile.hero>.c>.L p,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R .apd,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R .price .L,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R .price .R,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R>.info,
#     #MEA3-honormagc6pro-mobile.hero>.c>.B span.das,
#     #MEA3-honormagc6pro-mobile.hero>.c>.B>span {color: var(--clr-black);}
#     #MEA3-honormagc6pro-mobile.hero>.c>.L picture img {max-width: 100%; height: auto;}
#     #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.tab {display: none;}
#     #MEA3-honormagc6pro-mobile.hero>.c>.B span.das:after {background-image: url(https://static.s-sfr.fr/assets/pictos/aide_plein_40_noir.svg);}
#
#     #MEA4-TF_Mars_box_high_tech{background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/desk_vague-bleue-neon_bg_acc.webp); background-size: cover; background-position: left;}
#
#     @media all and (max-width: 1100px){
#         #MEA1-iphone15-mobile{ background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_brume-violette_bg_acc.webp); background-position: center;}
#
#         #MEA2-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_famille-canape_bg_acc.webp);}
#         #MEA2-TF-Mars-Fibre-fixe-SCD.hero>.c>.L strong br {display: none;}
#
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.tab {display: block;}
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.mob {display: none;}
#
#         #MEA4-TF_Mars_box_high_tech{background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_vague-bleue-neon_bg_acc.webp); background-position: center;}
#     }
#
#     @media all and (max-width: 768px){
#         #MEA1-iphone15-mobile{ background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/mob_brume-violette_bg_acc.webp);}
#
#         #MEA2-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/mob_famille_canape_bg_acc_v2-min.webp); background-position: right top;}
#         /*
#         #MEA1-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/mob_famille_canape_bg_acc_v2.webp); background-position: right top;}
#         */
#         #MEA3-honormagc6pro-mobile.hero>.c>.L {margin: -98px 0 0 0;}
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.tab {display: none;}
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.mob {display: block;}
#
#         #MEA4-TF_Mars_box_high_tech{background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_vague-bleue-neon_bg_acc.webp);}
#     }
#
# </style>
# <script src="//static.s-sfr.fr/rbhg.js"></script>
# </head>
# <body class="Home">
# <!--prod-->
# <!--https://www.sfr.fr-->
# <style>
# @font-face{font-family:PI;src:url(//static.s-sfr.fr/img/pic.woff)}
# @font-face{font-family:SR;src:url(//static.s-sfr.fr/assets/fonts/Poppins-Regular.woff2)}
# @font-face{font-family:SB;src:url(//static.s-sfr.fr/assets/fonts/Poppins-Bold.woff2)}
# @font-face{font-family:SD;src:url(//static.s-sfr.fr/assets/fonts/Poppins-Black.woff2)}
# html,body{overflow-x:hidden}
# body{margin:0;padding:0}
# body:before{height:0}
# body.Home #eThS{transition:top .3s}
# body.hF:not(.basket-displayed):before{display:block;content:''}
# body.hF:not(.basket-displayed) #eThS{position:fixed;top:0}
# body:not(.Media) #eThS{box-shadow:0 4px 9px 0 #2222}
# body.hM:after,body.hL:after,#eThS.hL:after{content:"";position:fixed;z-index:62000;width:100%;height:100%;top:0;left:0;background:#0003;backdrop-filter:blur(2px)}
# html>body.hL{max-height:100vh;overflow:hidden!important}
#
#
# #eThS,#eThS *,#eThS :before,#eThS :after{display:inline-block;position:static;box-sizing:border-box;font:inherit;color:inherit;background:#0000;margin:0;padding:0;min-width:0;max-width:none;width:auto;height:auto;text-align:inherit;vertical-align:top;box-shadow:none;border:0;border-radius:0;outline:0;user-select:none;-webkit-font-smoothing: antialiased}
# #eThS{position:relative;visibility:visible;z-index:62100;font:0/1.2 SR,Arial;color:#181818;background:#fff;width:100%;word-break:normal;text-align:center}
# #eThS.hL:after{z-index:1}
# #eThS.rs .Z{transition:none}
# #eThS a,#eThS label,#eThS li,#eThS .CN,#eThS .Z>i{text-decoration:none;cursor:pointer}
# #eThS sup{font-size:70%;transform:translateY(-4px)}
# #eThS b{display:inline;font-family:SB,Arial}
# #eThS [data-pi]{font:0/0 Arial}
# #eThS [data-pi]:before{font:1em/1 PI;white-space:pre;content:attr(data-pi)}
# #eThS [data-n]{position:relative}
# #eThS [data-n]:after{position:absolute;left:calc(50% + 12px);top:20%;transform:translateX(-50%);font:10px/1 SR;padding:2px 3px;content:attr(data-n);color:#fff;background:#D90D25;min-width:14px;text-align:center;border-radius:8px}
# #eThS input[id],#eThT .F,#eThT>.EC>label,#eThT>.EC .C,#eThT>.EC .NO,#eThT>div.EC.C.O>*,#eThT>.EC.C .D,nav#eThM>*{display:none}
# #eThS>nav,#eThS>nav>div,nav#eThM .W,#eThM .W a,#eThM>.Z p,#eThS .Z>i,#eThT>.EC.C .C,#eThT>.EC.C.O>.NO{display:block}
# #eThT>.EC.C p.CN{display:inline-block}
# #eThT>.EC.O>.CN{font-size:0}
# #eThT>.EC.O>.CN:after{font-size:12px;content:'Retour'}
# #eThS .W{position:relative;text-align:left}
# #eThS .Z{position:absolute;z-index:5;text-align:center;left:0;top:56px;width:100%;background:#fff;transform-origin:top;transform:scaleY(0);transition:.3s .1s transform}
# #eThS .Z>*{opacity:0;transition:.2s opacity}
# #eThS .RED{color:#D90D25;font-family:SB,Arial}
# #eThT .SFR:before{font-size:56px;color:#fff;background:#e2001a}
# #eThT form{color:#000;background:#f2f2f2;border-radius:8px}
# #eThT input{padding:0 0 0 16px;font:14px/40px SR,Arial;width:calc(100% - 40px)}
# #eThT .OK{height:40px;width:40px;text-align:center}
# #eThT .OK:before{font:22px/40px PI}
# #eThT>.W>p{position:absolute;right:4px}
# #eThT p>*{padding:0 12px}
# #eThT p>[data-pi]:before{font:24px/56px PI}
# #eThT p>[data-ec]:before{font:10px/2 SB,Arial;content:attr(data-ec);color:#D90D25;border:2px solid #D90D25;border-radius:50%;width:24px;display:block;text-align:center;margin:16px 0;text-shadow:none}
# #eThPL:checked~.PL,#eThRE:checked~.RE,#eThEC:checked~.EC{transform:scale(1)}
# #eThPL:checked~.PL>*,#eThRE:checked~.RE>*,#eThEC:checked~.EC>*,#eThMB:checked~#eThT .MB>*{opacity:1;transition:.1s .3s opacity}
# #eThPL:checked~.W [for=eThPL],#eThRE:checked~.W [for=eThRE],#eThT [for=eThEC],#eThMB:checked~#eThT [for=eThMB],#eThT .PT.O{color:#D90D25}
# #eThMB:checked~#eThT [for=eThMB]:before{content:"l"}
# #eThT>.PL>a{margin:8px;padding:20px 8px;width:140px;font:14px/22px SB,Arial;border-radius:8px}
# #eThT>.PL>a:before{display:block;font:32px/1 PI}
# #eThT>.RE{height:auto;text-align:left;padding:72px 16px 16px;font:14px/1.5 SB,Arial;color:#8a8a8a}
# #eThT>.RE>p{display:block;margin:8px 0 0;font:24px/1.5 SB,Arial;cursor:pointer}
# #eThT>.RE>p:hover{background:#eee}
# #eThT>.RE b{padding:0;color:#181818}
# #eThT>.EC{padding:24px;text-align:center}
# #eThT>.EC>*{display:block;font:14px/22px SR,Arial;;margin:0 0 16px}
# #eThT>.EC>a{max-width:352px;margin:0 auto;padding:8px 0}
# #eThT>.EC>.T{font:24px/1.5 SB,Arial}
# #eThT>.EC>.T:before{display:block;font-size:36px}
# #eThT>.EC>.B,#eThT>.EC>.X{text-align:center;max-width:352px;font:14px/16px SB,Arial;padding:12px 24px;margin:16px auto;width:auto;border-radius:8px;transition:box-shadow .3s}
# #eThT>.EC>.B{color:#fff;background:#D90D25;box-shadow:0 4px 8px #9003}
# #eThT>.EC>.B:hover{box-shadow:0 4px 8px #9005}
# #eThT>.EC>.X{background:#0000;color:#181818;border:1px solid #181818}
# #eThT>.EC>.X:hover{box-shadow:0 4px 8px #2226}
# #eThT [for].EC.C:before{margin:8px -8px;width:40px;border-radius:8px;font:14px/36px SB,Arial;border-width:2px}
# #eThT [for].EC.C:after{left:calc(50% + 18px);top:8%}
# #eThT .CN,#eThM .NEW:after{display:inline-block;margin:16px auto 0;padding:0 8px;color:#D90D25;background:#fee;border-radius:4px;font:12px/1.5 SB,Arial}
# #eThT .NO{background:#fcfcfc;border:0 solid #ccc;border-width:1px 0 0;margin:24px 0;max-height:80vh;overflow:auto}
# #eThT .NO>div{display:block}
# #eThT>.MB{height:calc(100vh - 56px)}
# #eThM .NEW:after{content:'Nouveau';white-space:nowrap;margin:3px 0 0 8px}
# #eThM>.Z p{font:24px/1.5 SB,Arial;margin:16px 0}
# #eThM>.Z a{font:14px/22px SR,Arial;margin:0 0 8px}
# #eThM>.Z:after{content:none}
# #eThM .W>div{display:block;margin:0 0 8px}
# #eThT .EC a:before,#eThM .W [data-pi]:before{font:24px/1 PI;margin:0 8px 0 0}
# #eThM .W p[data-pi]:before{font:24px/1.5 PI}
# #eThM .W>.DC{background:#f2f2f2;border-radius:8px}
# #eThM .W>.DC a{margin:0 0 16px}
# #eThM .W>.SEO{width:99%;max-width:none;padding:16px 0}
# #eThM div.SEO>a{display:inline-block;margin:0 12px 8px;padding:0 12px;border:1px solid #a0a0a0;border-radius:12px}
#
# .Media #eThS,.Media #eThS .SFR,.Media #eThS .RED,.Media #eThS [data-ec],.Media #eThS .B,.Media #eThMB:checked~#eThT [for=eThMB],
# .Media #eThPL:checked~.W [for=eThPL],.Media #eThRE:checked~.W [for=eThRE],.Media #eThT [for=eThEC],.Media #eThMB:checked~#eThT [for=eThMB],
# .Media #eThS [data-n]:not(.EC):after,.Media #eThS .NO,.Media #eThT .PT.O{filter:invert(1)}
# .Media #eThS{color:#000;background:#ddd}
# .Media #eThS .CN,.Media #eThS .NEW:after{filter:invert(1);background:#222}
#
# .Media #eThS form{background:#e7e7e7}
#
#
#
#
# @media(max-width:960px){
# body.hL::-webkit-scrollbar{display:none}
# #eThS.hL:after{height:0}
# #eThT .F,#eThM{opacity:0;transition:.2s .3s opacity}
# #eThT .F{display:block;position:absolute;top:-99px}
# #eThT form{opacity:0;width:80px;position:relative;z-index:-1}
# #eThRE:checked~.W form{position:absolute;top:72px;left:16px;z-index:6;width:calc(100% - 32px);opacity:1;transition:.1s .2s opacity}
# #eThMB:checked~#eThT .MB{transform:scale(1)}
# #eThMB:checked~#eThT .F{opacity:1;display:block;position:absolute;z-index:7;text-align:left;width:100vw;padding:4px 16px;right:-4px;font:14px/22px SR,Arial}
# #eThT .F[data-pi]:before{position:relative;font:20px/1.2 PI;margin:0 8px 0 0}
# #eThMB:checked~#eThT .F:nth-child(1){top:340px;font:24px/1.5 SB,Arial}
# #eThT .F:nth-child(1):before{content:none}
# #eThMB:checked~#eThT .F:nth-child(2){top:calc(84vh - 80px)}
# #eThMB:checked~#eThT .F:nth-child(3){top:calc(84vh - 48px)}
# #eThMB:checked~#eThT .F:nth-child(4){top:calc(84vh - 16px)}
# #eThT>.PL>a{max-width:40vw}
# #eThMB:checked~#eThM{opacity:1;position:absolute;top:56px;left:0;width:100%;z-index:6;text-align:left;padding:16px}
# #eThMB:checked~#eThM>a{display:block;font:24px/1.5 SB,Arial;margin:8px 0 0}
# #eThS .Z>i{font:0/1 Arial;text-align:left;display:block;margin:16px 0 0}
# #eThS .Z>i:after{content:'m';font:32px/1 PI}
# #eThM>a{white-space:nowrap}
# #eThM>.Z,#eThT>.PL{transform:scaleX(0);transform-origin:right;right:0;top:0;padding:0 16px;display:block;z-index:8}
# #eThM .Z.O{transform:scale(1)}
# #eThM .Z.O>*{opacity:1}
# #eThM .W{max-height:calc(100vh - 84px);overflow:auto;padding-bottom:80px}
# #eThT>.PL{height:calc(100vh - 56px);top:56px}
# #eThM [data-af]:after{content:attr(data-af);padding-left:6px}
# #eThM .W>.DC{padding:4px 16px;margin:24px 0 16px}
# #eThT>.EC>a{max-width:256px;text-align:left}
# body.hF:before{height:56px}
# }
# @media(min-width:960.1px){
# #eThS.hL:after{position:absolute;height:126px}
# #eThS .W{max-width:1344px;width:100%;margin:0 auto;padding:0 32px}
# #eThS .Z{top:70px}
# #eThT .SFR:before{font-size:70px}
# #eThT form,#eThT .F{display:inline-block}
# #eThT form{width:calc(100% - 680px);margin:15px 40px;transition:all .3s;position:static}
# #eThT form.A{margin:15px calc(50% - 376px);width:520px}
# #eThT p>*{padding:0 16px}
# #eThT .F:not(.X){font:14px/48px SR,Arial;padding-top:4px;border-bottom:4px solid #0000}
# #eThT .F:not(.X):before{content:none}
# #eThT>.W>p{top:7px;right:16px}
# #eThT>.PL{padding:32px 0}
# #eThT>.PL>a:hover{background:#fee;color:#D90D25}
# #eThT [for].EC{margin:0 8px 0 0}
# #eThT [for].EC:before{margin:8px -8px;width:40px;border-radius:8px}
# #eThT [for].EC:not(.C):before{display:block;text-align:center;color:#fff;background:#D90D25;font:24px/40px PI}
# #eThT [for].EC.C:before{font:14px/36px SB,Arial;border-width:2px}
# .Media #eThT>.PL>a:hover{background:#cff;color:#26f2da}
# #eThT>.PL>a.hi{color:#D90D25}
# .Media #eThT>.PL>a.hi{color:#26f2da}
# #eThT p>.RE,#eThT .MB,#eThT form.A+p>.F{display:none}
# #eThT>.EC{text-align:left;top:0;padding-top:44px;left:auto;right:0;width:400px;height:100vh;transform-origin:right;transform:scaleX(0)}
# #eThT>.EC>.T{margin-top:80px}
# #eThT>.EC:after{right:100%;top:0;width:900vw;height:100vh}
# #eThT>.EC>label{display:block;position:absolute;left:24px;top:24px;width:24px;height:24px;background:#181818;color:#fff;border-radius:50%;font-size:0}
# #eThT>.EC>label:before{font:12px/2 PI;padding:0 6px}
# #eThM>a{display:inline-block;font:14px/48px SR,Arial;padding:4px 20px 0;border-bottom:4px solid #0000}
# #eThM>a:hover{border-color:#7777}
# #eThT .hi{color:#D90D25}
# .Media #eThT .hi{color:#26f2da}
# #eThM>a.hi{border-color:#D90D25}
# .Media #eThM>a.hi,.Media #eThN>.W>a.hi{border-color:#26f2da}
# #eThT>.RE{min-height:56px;padding:16px calc(50% - 300px)}
# #eThS .Z>i{display:none}
# #eThM>a+.Z{top:126px;transition:0s box-shadow,.3s .1s transform}
# #eThM>a:hover+div,#eThM>div:hover{box-shadow:0 24px 24px #0002;transform:scale(1);transition:.3s box-shadow,.3s .1s transform}
# #eThM>a:hover+div>*,#eThM>div:hover>*{opacity:1;transition:.1s .3s opacity}
# #eThM .W,#eThM .W>.SEO{text-align:center}
# #eThM .W>div{text-align:left;display:inline-block;padding:8px calc(8% - 64px) 8px 0;max-width:25%}
# #eThM .W>.DC{padding:0 24px 8px;margin:8px 0}
# #eThM .W a{color:#555}
# #eThM .W a:hover{color:#000}
# body.hF:before{height:126px}
#
# }
# @media(min-width:1200px){
# #eThT form{width:332px}
# #eThT .F.X{font:14px/48px SR,Arial;padding-top:4px;border-bottom:4px solid #0000}
# #eThT .F.X:before{content:none}
# }
# </style>
# <header id="eThS"><input id="eThMB" type="checkbox"/>
# <nav id="eThT"><input id="eThPL" type="checkbox"/><input id="eThRE" type="checkbox"/><input id="eThEC" type="checkbox"/>
# <div class="W"><a class="SFR" data-pi="@" href="https://www.sfr.fr/" title="SFR">SFR</a><form action="https://www.sfr.fr/recherche" autocomplete="off"><input name="q" placeholder="Rechercher un téléphone, un service, ..." type="text"/><button class="OK" data-pi="G" title="Rechercher" type="submit"></button></form><p><label class="PL F" data-pi="H" for="eThPL" title="Apps &amp; services">Apps &amp; services</label><a class="F" data-pi="p" href="https://www.sfrbusiness.fr/offres-pro/?utm_source=referrer&amp;utm_medium=sfr.fr&amp;utm_campaign=Pro_header" title="Pro">Pro</a><a class="F X" data-pi="I" href="https://assistance.sfr.fr/" title="Aide">Aide</a><a class="F X" data-pi="U" href="https://boutique.sfr.fr/" title="Trouver une boutique">Trouver une boutique</a><label class="RE" data-pi="G" for="eThRE" title="Recherche">Recherche</label><a class="PT" data-hi="0" data-pi="D" href="https://www.sfr.fr/#sfrpt" title="Panier">Panier</a><a data-pi="E" href="https://webmail.sfr.fr/" title="Mail">Mail</a><label class="EC" data-pi="a" for="eThEC" title="Client">Client</label><label class="MB" data-pi="B" for="eThMB" title="Menu">Menu</label></p></div>
# <div class="Z PL"><i>Retour</i><a data-pi="a" href="https://u.sfr.fr/s/accueil?sun_source=header_siteweb" title="SFR &amp; Moi">SFR &amp; Moi</a><a data-pi="L" href="https://actus.sfr.fr/" title="SFR Actus">SFR Actus</a><a data-pi="M" href="https://tv.sfr.fr/" title="TV sur PC">TV sur PC</a><a data-pi="N" href="https://www.sfrcloud.sfr.fr/" title="SFR Cloud">SFR Cloud</a><a data-hi="home@|home.boutique@" data-pi="O" href="https://boutique.home.sfr.fr/" title="SFR Home">SFR Home</a><a data-pi="H" href="https://www.sfr.fr/sfr-et-moi/vos-applis-sfr.html" title="Toutes les apps">Toutes les apps</a></div>
# <div class="Z RE"></div>
# <div class="Z EC"><p class="T" data-pi="a">Espace Client</p><p class="D">Identifiez-vous pour accéder à votre Espace Client</p><p class="CN C">Centre de notification</p><a class="B D" href="https://www.sfr.fr/mon-espace-client/" title="Se connecter">Se connecter</a><a class="B C" href="https://www.sfr.fr/mon-espace-client/" title="Accéder à l'Espace Client">Accéder à l'Espace Client</a><a class="X C" href="https://www.sfr.fr/auth/realms/sfr/protocol/openid-connect/logout?redirect_uri=https%3A//www.sfr.fr/cas/logout%3Furl%3Dhttps%253A//www.sfr.fr/" title="Se déconnecter">Se déconnecter</a><a data-pi="Z" href="https://assistance.sfr.fr/actes-urgence.html" title="Accès aux actes d'urgence">Accès aux actes d'urgence</a><a class="C" data-pi="I" href="https://www.sfr.fr/routage/identifiant" title="Mots de passe et sécurité">Mots de passe et sécurité</a><a class="C" data-pi="Y" href="https://www.sfr.fr/routage/gestionlignes" title="Rattacher / Retirer mes lignes">Rattacher / Retirer mes lignes</a><a class="D" data-pi="T" href="https://www.sfr.fr/suivi-commande/" title="Suivi de commande">Suivi de commande</a><a class="C" data-pi="T" href="https://espace-client.sfr.fr/suivre-ma-commande/authentification" title="Mes commandes">Mes commandes</a><a data-pi="d" href="https://www.sfr.fr/offre-internet/demenagement" title="Déménagement">Déménagement</a><div class="NO"></div><label class="eThX" data-pi="C" title="Fermer">X</label></div><div class="Z MB"></div>
# </nav>
# <nav id="eThM"><a href="https://www.sfr.fr/offre-internet" title="Box internet">Box internet</a><div class="Z"><i>Retour</i><div class="W"><div><p data-pi="W">Offres</p><a href="https://www.sfr.fr/offre-internet" title="Box Internet  ">Box Internet  </a><a href="https://www.sfr.fr/offre-internet/internet-partout" title="Internet partout">Internet partout</a><a href="https://www.sfr.fr/offre-internet/options" title="Options Box">Options Box</a></div> <div><p data-pi="X">Equipements</p><a class="NEW" href="https://www.sfr.fr/offre-internet/box-high-tech" title="Box + High Tech">Box + High Tech</a><a href="https://www.sfr.fr/box-8/" title="SFR Box 8X">SFR Box 8X</a><a href="https://www.sfr.fr/offre-internet/box-internet" title="Box et décodeurs">Box et décodeurs</a><a href="https://www.sfr.fr/options/repeteur-wifi6" title="Répéteur WiFi">Répéteur WiFi</a><a href="https://www.sfr.fr/accessoires/maison-connectee-et-gaming" title="Accessoires Box">Accessoires Box</a></div> <div><p data-pi="c">Avantages SFR</p><a href="https://www.sfr.fr/carte-couverture-reseau-sfr-fibre-optique/" title="Couverture réseau Internet et fibre">Couverture réseau Internet et fibre</a><a data-hi="0" href="https://www.sfr.fr/internet-mobile/sfr-family" title="Avantages Box + Mobile">Avantages Box + Mobile</a><a href="https://www.sfr.fr/offre-internet/frais-resiliation" title="Changer d'opérateur">Changer d'opérateur</a></div> <div class="DC"><p>Déjà client</p><a data-pi="W" href="https://www.sfr.fr/mon-espace-client/redirect.html?D=FCHANGE" title="Changer d'offre">Changer d'offre</a><a data-pi="d" href="https://www.sfr.fr/offre-internet/demenagement" title="Déménagement Internet">Déménagement Internet</a><a data-hi="0" data-pi="b" href="https://www.sfr.fr/espace-client/options/" title="Gérer vos options Box ">Gérer vos options Box </a></div> <div class="SEO"><a href="https://www.sfr.fr/offre-internet/box-high-tech#tablette" title="Tablette Samsung Galaxy Tab A9+">Tablette Samsung Galaxy Tab A9+</a><a href="https://www.sfr.fr/offre-internet/box-high-tech/casque-meta-metaquest3" title="Casque VR Meta Quest 3">Casque VR Meta Quest 3</a><a href="https://www.sfr.fr/offre-internet/box-high-tech/samsung-tv-cu7105-43" title="Smart TV Samsung">Smart TV Samsung</a><a href="https://www.sfr.fr/offre-internet/fibre-optique" title="La Fibre de SFR">La Fibre de SFR</a></div></div></div><a href="https://www.sfr.fr/offre-mobile" title="Forfaits mobile">Forfaits mobile</a><div class="Z"><i>Retour</i><div class="W"><div><p data-pi="i">Offres</p><a href="https://www.sfr.fr/offre-mobile" title="Forfait mobile 5G / 4G+">Forfait mobile 5G / 4G+</a><a href="https://www.sfr.fr/offre-mobile/decouvrir-la-5g" title="5G de SFR">5G de SFR</a><a href="https://www.sfr.fr/offre-mobile/options" title="Options mobile">Options mobile</a><a href="https://www.sfr.fr/offre-mobile/international" title="International">International</a><a data-hi="0" href="https://www.sfr.fr/offre-internet/internet-partout" title="Internet partout">Internet partout</a><a href="https://www.sfr.fr/offre-mobile/carte-prepayee" title="Carte prépayée">Carte prépayée</a></div> <div><p data-pi="c">Avantages SFR</p><a href="https://www.sfr.fr/reseau/carte-couverture-reseau-mobile.html" title="Couverture réseau mobile 4G et 5G">Couverture réseau mobile 4G et 5G</a><a href="https://www.sfr.fr/offre-mobile/bonus-smartphone" title="Bonus smartphone">Bonus smartphone</a><a data-hi="0" href="https://www.sfr.fr/internet-mobile/sfr-family" title="Avantages Box + Mobile">Avantages Box + Mobile</a></div> <div class="DC"><p>Déjà client</p><a data-pi="i" href="https://www.sfr.fr/offre-mobile?context=change&amp;parcours=offre" title="Changer d'offre">Changer d'offre</a><a data-hi="0" data-pi="b" href="https://www.sfr.fr/espace-client/options/" title="Gérer vos options mobile">Gérer vos options mobile</a><a data-pi="k" href="https://www.sfr.fr/options/multisurf" title="Multisurf : SIM additionnelle">Multisurf : SIM additionnelle</a></di ...
# <label class="eThX"></label>
# </header>
# <script>!function(W,_,o){if(_=W._eT){
# _.h23=1;if(o=_('#eThS~#eThS')[0]){var p=o.previousElementSibling;if(p.tagName=='STYLE')_(p).R();_(o).R()}
# var D=_('body'),H=_('#eThS'),h=H._,b,B,C='',E=h('.E>p').H(),M,P,n=_.ckR('eTpT'),p=h('#eThP'),L0=0,O1,O2,ott,mw,na,hM=0,u,YO,
#     q=_('#eThT [name=q]'),Q,R=_('#eThT>.RE'),AC=[],QS=["Recherches populaires","iPhone 15","Éligibilité Fibre","Bons plans","Samsung Galaxy S24"],
#     ac=function(){
#         Q=_.ac0((q[0].value||'').toLowerCase()).replace(/[^-a-z0-9]/g,' ');
#         D.C('hL');_('#eThRE').F('checked',!0);
#         if(Q&&!AC[Q])_.JS((Q[4]?'//www.':'//static.s-')+'sfr.fr/recherche/jsp/ac.jsp?q='+Q);else R.H(Q?AC[Q]:QS.join('<p><b>'));
#         R._('p').cl(function(){q.F('value',this.innerText).F('form').submit()})},
#     wm=e=>W.innerWidth<=960,
#     fN=n=>/^[0-9]{10}$/.test(n)?n.replace(/([0-9][0-9])/g,'$1 '):n,
#     fq=function(){h('form').C('A',this===document.activeElement?0:1)},
#     m0=e=>{h('.Z.O').C('O',1);h('#eThT .F').S('visibility','visible')},
#     pD=e=>e.preventDefault(),
#     hi=H[0].hi=function(L){
#         var l,m=0,O,o,s=' a[href]:not([data-hi="0"])',t,R='replace',A,
#             f=function(o,h,d){h=o.href;d=_(o).at('data-hi');l=h.length;
#                 if(l>=m&&L.indexOf(h)==0||d&&RegExp('^('+d[R](/E/g,'(espace-client)?@')+')').test(
#                     L[R](/^https?:../,'')[R](/.sfr.fr/,'@')[R](/(www(.pfv)?|cms|futpsw)@/,'@'))){O=o;m=l}};
#         L=L||location.href;if(L!=L0){L0=L;O1=O2=0;h('.hi').C('hi',1)}
#         O=m=0;h('#eThT '+s).E(f);if(O&&O!=O1){o=_(O1=O).C('hi').P('.PL');if(o[0])h('[for=eThPL]').C('hi')}
#         O=m=0;h('#eThM'+s).E(f);if(O&&O!=O2){o=_(O2=O).C('hi').P('.Z')[0];if(o)_(o.previousElementSibling).C('hi')}
#
#     };
#
# h('label').at('tabindex','0');
# h('.PT').cl(e=>{pD(e);_.paI()});
#
#
# if(_('body.Home')[0])if(_.ckR('eTab993')>1)_(W).ev('scroll',y=>{y=pageYOffset;if(y>99&&!D.C('hF',3)){H.S('top','-128px');if(y<YO)_.to(e=>H.S('top',0),99)}D.C('hF',y<YO?0:1);YO=y});else D.C('hF');
#
# W.AC=function(q,r){if(q){
#     AC[q]='<p>'+r.split('~').join('<p>');
#     if(Q==q)ac()}};
# q.ev('focus',ac).ev('keyup',ac).ev('blur',function(){H.b=1;_.to(function(){D.C('hL',H.b);_('#eThRE').F('checked',!1);R.H('')})});
#
# hi();
# q.ev('focus',fq).ev('blur',fq);
# h('#eThT [for],.eThX').cl(function(){
#     var r,i=_(this).at('for');
#     h('#eThM .O').C('O',1);
#     h('[type=checkbox]').E(function(o){if(o.id!=i&&!(i=='eThPL'&&wm()))o.checked=!1;else r=o.checked});
#     D.C('hL',H.b=r||!i?1:0);
#     H.C('hL',i=='eThEC'?0:1);
#     if(!r&&i=='eThRE')_.to(e=>{q[0].click();q[0].focus()},333)});
# h('#eThM>a').cl(function(e,o){if((o=this.nextSibling)&&o.tagName!='A'){
#     if(wm()){h(o).C('O');h('#eThT .F').S('visibility','hidden');pD(e)}else if(!D.C('hM',3))pD(e)}});
# h('#eThM>.Z>i').cl(m0);
# h('.PL>i').cl(e=>h('#eThPL').cl());
# h('.CN').cl(function(){_(this).P().C('O',2)});
# h('nav,#eThMB').cl(e=>e.stopPropagation());
# D.cl(e=>{if(e.layerY>0){h(':checked').F('checked',!1);_('.hL').C('hL',1)}});
#
# h('a[href]').E(o=>{
#     var u=o.href.replace(/^https:..(cms|www).sfr.fr/,''),n;
#     if(RegExp('^('+_.nbP+')').test('@'+u))_(o).cl(e=>{
#         n=o.nextSibling;
#         if(!na||wm()&&n&&/Z/.test(n.className))return;
#         s_objectID=o.href;
#         H.af();_.to(e=>H.af(1),5);
#         if(_('#eThMB')[0].checked)_.to(e=>{m0();_('[for=eThMB]').cl()},5);
#         pD(e);na(u);_.to(hi)})});
#
#
#
# _(W).ev('resize',e=>{H.C('rs');_.to(e=>H.C('rs',1),2e3)});
#
# h('#eThM>a').ev('mouseover',function(){hM=wm()?0:2});
#
# _.ti(function(c){
#     na=na||W.newSFRNavigateTo;
#
#     var p=_.Prenom,n=_.Nom,c=W.zvars.eVar4||'',m='',L=_.lse(1)||'',b=0;
#     if(hM>0){h('#eThM .Z').E(function(o){b+=/1, 0, 0, 0, 0, 0/.test(_(o).S('transform'))?0:1});if(b)D.C('hM'),hM=1;else if(--hM<1)D.C('hM',1)}
#     if(c){c+=L[0]||'';m=_.ckR('eTnm')*1}
#     if(H.nm!=m){H.nm=m;h('[data-pi=E]').at('data-n',m<1?undefined:m>999?(m/1e3|0)+'k':m)}
#     if(c!=C){
#
#         C=c;h('.EC').C('C',C?0:1);h('p>.EC').at('data-ec',C?(p?p[0]:'')+(n?n[0]:'')||'  ?  ':0);
#         h('.EC .T').H(C?'Bonjour'+(p+n?',<br>'+p+' '+n:''):E)}});
#
#
# }}(window)</script>
# <main>
# <section id="Acc5">
# <div class="heroes">
# ...
#         </p></div>
# </details>
# <hr/>
# <details>
# <summary>
# <span>Mentions légales</span>
# </summary>
# <div>
#             *Avec SFR Fibre Premium sous réserve d’éligibilité, débit théorique maximum depuis un équipement compatible branché en filaire grâce au module SFR Box 8X fourni sur demande.<br/>
#             *Offres soumises à conditions en France métropolitaine.<br/><br/>
# <strong>Conditions du casque :</strong><br/>Consulter les conseils pour la sécurité en ligne des enfants. Comptes pour des utilisateurs de 10 ans et plus.<br/>Asgard’s Wrath 2 est destiné à un public adulte<br/><br/>
# <strong>Un crédit vous engage et doit être remboursé. Vérifiez vos capacités de remboursement avant de vous engager.</strong> Exemple pour l’achat d’un achat à 1229 € avec un crédit en 24X : Paiement comptant de 749 € puis 24 <strong>mensualités de 20,00 €/mois. TAEG fixe : 0%.</strong> Taux débiteur fixe de 0%. <strong>Montant total dû par l’emprunteur : 480 € (hors assurance facultative).</strong> Coût de l’assurance facultative de 0,82 € par mois en plus de la mensualité. Le taux effectif de l’assurance est de 0.17%. Sous réserve d’acceptation par FLOA. Vous disposez d’un délai de rétractation. Coût du crédit pris en charge par SFR. Voir conditions sur <a href="http://c.sfr.fr/credit">http://c.sfr.fr/credit</a>
# <br/><br/>
# <strong>BONUS REPRISE</strong> : offre soumise à conditions, valable en France métropolitaine, réservée aux abonnés mobile SFR ou RED by SFR, pour l’achat d’un mobile éligible (hors mobile seul) associé à la reprise d’un ancien mobile sur sfr.fr ou redbysfr.fr. Versement du bonus reprise entre 40 jours et 60 jours après la validation de la commande. Conditions et détails dans les conditions particulières du bonus reprise.
#         <br/><br/>
# <strong>REPRISE MOBILE</strong> : offre soumise à conditions, valable en France métropolitaine, sur les sites internet sfr.fr ou redbysfr.fr, permettant à un client de céder la propriété d'un ou de plusieurs téléphones mobiles (dans la limite de 3 par an) en contrepartie d'un paiement en numéraire par SFR ou par un repreneur, partenaire de SFR. Voir conditions et détails sur <a href="https://www.sfr.fr/offre-mobile/tarifs-conditions" target="_blank" title="https://www.sfr.fr/offre-mobile/tarifs-conditions">https://www.sfr.fr/offre-mobile/tarifs-conditions</a>.
#         <br/><br/>
# <strong>RESEAU 5G</strong> : Réseau 5G de SFR, en cours de déploiement, valable sous réserve de couverture avec offre et terminal 5G compatibles. Réseau 5G 3,5 Ghz ou 2100 MHZ disponible selon les communes des agglomérations couvertes. Détails de couverture sur https://www.sfr.fr/couverture . La 5G présente des performances différentes suivant les fréquences utilisées, débit descendant maximum théorique (association des fréquences 4G et 5G dans les zones couvertes) de 2 Gb/s en bande de fréquence 3,5Ghz et de 995 Mb/s en bande de fréquence 2100 Mhz. La 5G est accessible depuis l’étranger avec une offre SFR et un terminal 5G compatibles, dans la limite des zones couvertes par les réseaux 5G des opérateurs étrangers ayant conclu un accord d’itinérance. Les débits 5G à l’étranger dépendent des opérateurs locaux partenaires de SFR.
#         <br/><br/>
# <strong>KIT MAIN LIBRE</strong> : L’utilisation d’un kit mains-libres est recommandée.
#         <br/><br/>
# <strong>MOBILE DEBLOQUES</strong> : Tous nos mobiles sont désimlockés, que qui signifie qu’ils peuvent être utilisés avec la SIM d’un autre opérateur.
#         <br/><br/>
# <strong>DAS</strong> : Le débit d’absorption spécifique (DAS) local quantifie l’exposition de l’utilisateur aux ondes électromagnétiques de l’équipement concerné. Le DAS maximal autorisé est de 2 W/kg pour la tête et le tronc et de 4 W/kg pour les membres. La mesure DAS tronc peut avoir été calculée par rapport à une certaine distance d'un organisme humain simulé. Reportez-vous à la brochure du constructeur.
#         <br/><br/>
# <strong>PAIEMENT EN 4 FOIS SANS FRAIS</strong> : Offre soumise à conditions, réservée aux abonnés mobiles SFR, personnes physiques majeures, domiciliés en France métropolitaine ou dans les DOM et titulaires d’une carte bancaire (Mastercard ou VISA) valable au moins 3 mois après la date de conclusion du contrat de paiement échelonné. Facilité de paiement, sans frais, d’une durée inférieure ou égale à 90 jours, en 4 échéances dont la première intervenant obligatoirement au jour de l’achat. Offre valable pour tout achat d’un terminal mobile et d’accessoires mobiles (uniquement avec l’achat d’un mobile) pour un montant total compris entre 50e et 3000€ (frais de port inclus), accompagné de la souscription simultanée d’un forfait mobile SFR avec un engagement 12 ou 24 mois ou dans le cadre d’un renouvellement de mobile (hors mobile et accessoires nus). Sous réserve d’acceptation du dossier par FLOA BANK, Société Anonyme au capital de 41 228 000 euros - Bâtiment G7, 71 Rue Lucien Faure, 33300 Bordeaux, RCS Bordeaux 434 130 423, ORIAS n°07 028 160 (www.orias.fr), Entreprise soumise au contrôle de l’Autorité de Contrôle Prudentiel et de Résolution (ACPR) 4 Place de Budapest, CS 92469, 75430 Paris Cedex 09<br/>https://www.floabank.fr/images/pdf/CB4X/Conditions-Gnrales-Vente-CB3X-CB4X.pdf
#         <br/><br/>
# <strong>FACILITE DE PAIEMENT</strong> : Offre réservée aux abonnés SFR (hors client RED by SFR et SFR Business) titulaires d'un forfait mobile SFR éligible. Selon l’offre et l’équipement éligibles choisis, solution de facilité de paiement d’un montant maximum de 192€, permettant de payer mensuellement (3, 5 ou 8€ /mois) une part du prix de l’équipement mobile sur une durée maximale de 24 mois, sans frais. Limité à une seule offre par ligne mobile. En cas de résiliation de la ligne ou de changement d’offre vers une offre inéligible, l’abonné devra régler l’intégralité des mensualités restant dues par anticipation.
#         <br/><br/>
# <strong>CREDIT EN 24 FOIS</strong> <span class="Text600"> <strong> : Un crédit vous engage et doit être remboursé. Vérifiez vos capacités de remboursement avant de vous engager.</strong> </span>
# <br/><br/>
# <strong><u>Exemple de financement d'un achat de 801€ avec un forfait SFR Avec un crédit affecté** en 24X</u></strong> : Paiement comptant de 81€ puis <span class="Text600"><strong>24 mensualités de 30,00€/mois.TAEG fixe  : 0%.</strong></span> Taux débiteur fixe de 0%. <span class="Text600"><strong>Montant total dû par l'emprunteur  : 720€</strong></span> (hors assurance facultative). Coût de l'assurance facultative de 1,23 € par mois en plus de la mensualité. Le taux effectif de l'assurance est de 0.17%. Coût du crédit pris en charge par SFR.
#             <br/><br/>
#             Offre soumise à conditions, réservée aux abonnés mobiles SFR, personnes physiques majeures, domiciliés en France métropolitaine ou dans les DOM. Offre valable pour tout achat d’un terminal mobile dont le financement est supérieur à 200€, accompagné de la souscription simultanée d’un forfait mobile SFR éligible ou dans le cadre d’un renouvellement de mobile (hors achat de terminaux mobiles nus). La dernière mensualité pourra être ajustée à la hausse comme à la baisse dans la limite de 0,50€.
#             <br/><br/>
#
#             SFR SA, 16 rue du Général Alain de Boissieu 75015 Paris - RCS paris N°343 059 564, ORIAS n° 12 065 393 (<a href="https://www.orias.fr" target="_blank" title="www.orias.fr">www.orias.fr</a>) agit en qualité de mandataire non exclusif en opérations de banque et en services de paiement de FLOA et apportant son concours à la réalisation d'opérations de crédit à la consommation sans agir en qualité de Prêteur.
#             <br/><br/>
#             *Exemple indicatif et sans valeur contractuelle calculé sur la base d’une première échéance 30 jours après la date du financement.
#             <br/><br/>
#             **Sous réserve d'acceptation du dossier par FLOA, RCS BORDEAUX 434 130 434 - Immeuble G7, 71 Rue Lucien Faure, 33300 BORDEAUX. ORIAS n°07 028 160 (<a href="https://www.orias.fr" target="_blank" title="www.orias.fr">www.orias.fr</a>). Vous disposez d’un délai légal de rétractation de 14 jours. Conditions en vigueur au 14/11/2023 et susceptibles de variation.
#             <br/><br/>
#             ***Soit 0,17% du capital emprunté par mois pour un emprunteur de moins de 66 ans pour les garanties Décès, Perte Totale et Irréversible d’Autonomie (PTIA) et Incapacité Temporaire Totale de travail (ITT). Contrat souscrit par FLOA auprès de ACM VIE SA (SA au capital de 778 371 392 €– RCS STRASBOURG 332 377 597 – Siège social : 4 rue Frédéric-Guillaume Raiffeisen - 67000 STRASBOURG Adresse postale : 63 Chemin Antoine Pardon, 69814 TASSIN cedex) et SERENIS ASSURANCES SA (SA au capital de 16 422 000€ – RCS ROMANS 350 838 686 – Siège social : 25 rue du Docteur Henri Abel, 26000 VALENCE - Adresse postale : 63 Chemin Antoine Pardon, 69814 TASSIN cedex), entreprises régies par le Code des Assurances.
#         </div>
# </details>
# </section>
# <script>
# _stats_pagename="Web/HomePages/Accueil/V6";
# _stats_univers="Home_Bout";
# </script>
# </main>
# <style>
# @font-face{font-family:ico;src:url(//static.s-sfr.fr/img/ico.woff)}
# #eTfS,#eTfS *{display:block;color:inherit;margin:0;padding:0;width:auto;height:auto;background:#0000;box-sizing:border-box;position:static;box-shadow:none;border:0;border-radius:0;font:inherit}
# #eTfS a{text-decoration:none;cursor:pointer}
# #eTfS input{display:none}
# #eTfS{background:#181818;position:relative;z-index:60000;width:100%;text-align:left}
# #eTfS:before{clear:both;content:" ";display:block}
# #eTfS>div{color:#fff;margin:0 auto;padding:0 16px 16px;text-align:left;line-height:0;position:relative;max-width:1344px}
# #eTfS input+div{border-bottom:1px solid #444;max-height:84px;padding:0 0 8px;overflow:hidden;transition:max-height .3s}
# #eTfS input:checked+div{max-height:400px}
# #eTfS p.T{position:relative;font:24px/1.5 SB,Arial;padding:24px 0}
# #eTfS label{position:absolute;top:0;display:block;cursor:pointer;width:100%;height:100%}
# #eTfS input:checked+div p.T>[for=T0]{z-index:1}
# #eTfS i{width:12px;height:12px;border:0 solid #fff;border-width:0 1px 1px 0;position:absolute;top:30px;right:3px;transform:rotate(45deg);transition:all .3s}
# #eTfS input:checked+div i{transform:rotate(225deg);top:38px}
# #eTfCOL p{font:14px/1.2 SR,Arial;padding:0 0 16px}
# #eTfSOC,#eTfBAS{width:100%;margin:24px 0 0}
# #eTfSOC{position:relative}
# #eTfSOC img{width:64px;height:auto}
# #eTfSOC>p{position:absolute;bottom:0;left:88px;font:16px/1.2 SB,Arial}
# #eTfSOC a{display:inline-block;font-size:0;margin:0 24px 0 0;vertical-align:top}
# #eTfSOC a+a:after{font:24px/1 ico}
# #eTfS [title=Facebook]:after{content:"V"}
# #eTfS [title=Twitter]:after{content:"Q"}
# #eTfS [title=YouTube]:after{content:"W"}
# #eTfBAS a{font:12px/1.5 SR,Arial;display:inline-block;margin:0 24px 8px 0;text-decoration:underline}
#
# @media(min-width:768px){
# #eTfS>div{padding:0 32px 16px;font-size:0}
# #eTfS p.T{font-size:18px}
# #eTfCOL p{font-size:12px}
# #eTfS input+div{display:inline-block;width:23%;margin-left:2.6%;max-height:none;vertical-align:top;border:0}
# #eTfS #T1+div{margin:0}
# #eTfS label{display:none}
# #eTfSOC img{width:80px}
# #eTfSOC>p{left:104px}}
#
# @media(min-width:1200px){
# #eTfCOL{margin-left:200px;padding-top:16px}
# #eTfSOC{position:absolute;top:16px;left:32px;width:144px}
# #eTfSOC>a:first-child{display:block;margin:0 0 24px}
# #eTfSOC>p{position:static;margin:24px 0}
# #eTfBAS{text-align:justify}
# #eTfBAS b{width:99%;height:1px;display:inline-block}}
# </style>
# <footer id="eTfS"><div><nav id="eTfCOL"><input id="T0" name="T" type="radio"/><input id="T1" name="T" type="radio"/><div><p class="T">S'informer<label for="T0"></label><label for="T1"><i></i></label></p><p><a href="https://www.sfr.fr/offre-mobile/tarifs-conditions">Tarifs</a></p><p><a href="https://www.sfr.fr/offre-internet/test-eligibilite-adsl-vdsl-fibre">Information sur les débits</a></p><p><a href="https://www.sfr.fr/engagements-rse/environnement/">Engagements RSE</a></p><p><a href="https://www.sfr.fr/reseau/carte-couverture-reseau-mobile.html">Couverture réseau mobile</a></p><p><a href="https://www.sfr.fr/carte-couverture-reseau-sfr-fibre-optique/">Couverture réseau Fibre et THD</a></p><p><a href="https://www.sfrbusiness.fr/">Offres Business</a></p><p><a href="https://tv.sfr.fr/guide">Guide TV</a></p><p><a href="https://www.sfr.fr/handicap/">Handicap</a></p></div> <input id="T2" name="T" type="radio"/><div><p class="T">Aide<label for="T0"></label><label for="T2"><i></i></label></p><p><a href="https://assistance.sfr.fr/tel-mobile/assu-panne-perte-vol/vol-perte-mobile.html">Mobile perdu ou volé ?</a></p><p><a href="https://espace-client.sfr.fr/gestion-securite/mot-de-passe/oublie/identifiant">Mot de passe oublié</a></p><p><a href="https://assistance.sfr.fr/form/incidents/reseau-fixe.html">Incidents fixe</a></p><p><a href="https://assistance.sfr.fr/form/incidents/reseau-mobile.html">Incidents mobile</a></p><p><a href="https://www.sfr.fr/sfr-et-moi/vos-applis-sfr.html">Applications mobile et services SFR</a></p><p><a href="https://la-communaute.sfr.fr">La Communauté SFR</a></p></div> <input id="T3" name="T" type="radio"/><div><p class="T">Espace Client<label for="T0"></label><label for="T3"><i></i></label></p><p><a href="https://u.sfr.fr/s/accueil?sun_source=footer_siteweb">Appli SFR &amp; Moi</a></p><p><a href="https://www.sfr.fr/suivi-commande/">Suivre ma commande</a></p><p><a href="https://www.sfr.fr/suivi-commande/">Activer ma ligne</a></p><p><a href="https://www.sfr.fr/offre-internet/demenagement">Déménagement</a></p><p><a href="https://espace-client.sfr.fr/odr/offres-remboursement/">Offres de remboursement</a></p><p><a href="https://www.sfr.fr/mon-espace-client/redirect.html?D=RESIL">Résilier</a></p></div> <input id="T4" name="T" type="radio"/><div><p class="T">Contacts<label for="T0"></label><label for="T4"><i></i></label></p><p><a href="https://www.sfr.fr/contacter/">Commander par téléphone</a></p><p><a href="https://assistance.sfr.fr/contacter/">Nous contacter</a></p><p><a href="https://dommages-reseaux.sfr.fr">Signaler un dommage réseau</a></p></div> </nav><nav id="eTfSOC"><a href="https://www.sfr.fr/"><img alt="SFR" src="//static.s-sfr.fr/assets/logos/SFR.svg"/></a><a href="https://fr-fr.facebook.com/SFR" title="Facebook">Facebook</a><a href="https://twitter.com/SFR" title="Twitter">Twitter</a><a href="https://www.youtube.com/channel/UCmOWXd_I8xsFRViDcQBNolA" title="YouTube">YouTube</a><p>Suivez-nous sur les réseaux </p></nav><nav id="eTfBAS"><a href="https://www.sfr.fr/mentions-legales.html">Informations légales</a> <a href="https://www.sfr.fr/plan-du-site.html">Plan du site</a> <a href="https://assistance.sfr.fr/sfrmail-appli/phishing-spam/proteger-phishing.html#sfrintid=">Phishing</a> <a href="https://www.sfr.fr/politique-cookies.html">Cookies</a> <a href="https://www.sfr.fr/politique-de-protection-des-donnees-personnelles.html">Données personnelles</a> <a href="https://www.sfr.fr/accessibilite/">Accessibilité</a> <a href="https://signalement.fftelecoms.org/">Signaler un contenu illicite</a> <a href="http://alticefrance.com/">Altice France</a> <b></b></nav></div></footer>
# <script>!function(W){
# var _=W._eT,F=_('#eTfS'),b=_.nbP,h0=0;
# _('body>footer,footer#footer').af();F.af(2);
#
# if(_.adC)_.JS('//static.s-sfr.fr/export/bloc/django/newsletter.json?callback=_eT.adC');
# if(!_.T(b))_.ti(function(h,m){m='marginTop';h=W.innerHeight-F[0].offsetTop+F.S(m).replace('px','')*1;if(h>h0+2||h<h0-2)F.S(m,(h0=h)>0?h+'px':0)});
# else F._('a[href]').E(function(o,h){h=o.href.replace(/^https:..(cms|www).sfr.fr/,'');
# if(RegExp('^('+b+')').test('@'+h.replace(/#.*/,'')))_(o).cl(function(e,n){if(n=W.newSFRNavigateTo){e.preventDefault();n(h);W.scrollTo(0,0);_('#eThS').C('TV',/^.tv-sfr/.test(h)?0:1)}})});
# }(window)</script>
# <script src="//static.s-sfr.fr/rbfg.js"></script>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="fr" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=5,user-scalable=yes" name="viewport"/>
#   <link href="https://static.s-sfr.fr/media/icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://static.s-sfr.fr" rel="preconnect"/>
#   <link as="font" crossorigin="anonymous" href="//static.s-sfr.fr/assets/fonts/Poppins-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="//static.s-sfr.fr/assets/fonts/Poppins-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link href="//static.s-sfr.fr/resources/css/base-1.0.0.css" rel="prefetch stylesheet" type="text/css"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    SFR | Forfait Mobile, Téléphone, Internet Fibre et ADSL, TV
#   </title>
#   <meta content="Découvrez les offres Mobile et Internet SFR : forfaits mobiles et smartphones, internet très haut débit Fibre, ADSL et box 4G+, et l'expérience TV. Bienvenue sur sfr.fr !" name="Description"/>
#   <script>
#    _is_authenticated=false;
# _stats_timestamp="1711365213145";
# sfrIstConfig=djangoUtils={};
# sfrIstConfig.context='static.s-sfr.fr';
#   </script>
#   <link href="https://www.sfr.fr/" rel="canonical"/>
#   <meta content="SFR | Forfait Mobile, Téléphone, Internet Fibre et ADSL, TV" property="og:title"/>
#   <meta content="Découvrez les offres Mobile et Internet SFR : forfaits mobiles et smartphones, internet très haut débit Fibre, ADSL et box 4G+, et l'expérience TV. Bienvenue sur sfr.fr !" property="og:description"/>
#   <meta content="https://static.s-sfr.fr/media/icon-192x192.png" property="og:image"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.sfr.fr/" property="og:url"/>
#   <meta content="SFR" property="og:site_name"/>
#   <meta content="100002952604097" property="fb:admins"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="https://twitter.com/SFR" name="twitter:site"/>
#   <meta content="SFR | Forfait Mobile, Téléphone, Internet Fibre et ADSL, TV" name="twitter:title"/>
#   <meta content="https://www.sfr.fr/" name="twitter:url"/>
#   <meta content="Découvrez les offres Mobile et Internet SFR : forfaits mobiles et smartphones, internet très haut débit Fibre, ADSL et box 4G+, et l'expérience TV. Bienvenue sur sfr.fr !" name="twitter:description"/>
#   <script type="application/ld+json">
#    {"@context": "https://schema.org","@type": "Organization", "url": "https://www.sfr.fr/", "logo": "https://static.s-sfr.fr/media/icon-192x192.png" }
#   </script>
#   <script type="application/ld+json">
#    {"@context": "https://schema.org","@type": "WebSite","name": "SFR","url": "https://www.sfr.fr/"}
#   </script>
#   <link as="image" href="https://static.s-sfr.fr/assets/backgrounds/accordeon/mob_brume-violette_bg_acc.webp" rel="preload"/>
#   <link as="image" href="https://static.s-sfr.fr/media/mobile/MEA/accordeon/mob_iphone-15-pro_acc.webp" rel="preload"/>
#   <style>
#    main { display: flex; flex-direction: column; background: #f2f2f2; }
# #Acc5 { order:1; }
# h1 { order: 2; font-family: 'SFR-Bold'; font-size: 32px; line-height: 36px; margin: 40px auto 24px; max-width: 1280px; width: calc(100% - 64px); text-align: left;}
# h2 { text-align: left; }
# #Pilier { order:3; }
# #Choose { order: 4; }
# #Best { order:5; }
# #Rea { order:6; }
# #News { order:7; }
# #eTav { order:8; }
# #SEO { order:9; }
# #Mentions { order:10; }
# #Pilier { padding: 0; display: none; }
# #TT { display: none; }
# #eTsNL { order:9; }
#
# #Acc5 { width: 100%; height: 460px; position: relative; overflow: hidden; }
# #Acc5 .heroes { position: relative; height: 100%; }
# #Acc5 .hero { position: relative; height: 100%; display:block; background-repeat: no-repeat; animation: fadein 1s ease-out; }
# #Acc5 .hero:before { content: ''; height: 296px; position: absolute; bottom: 0; left: 0; right: 0; width: 100%; background: rgba(226, 0, 0, 0.8); background-image: linear-gradient(360deg, var(--clr-sfr) 70%, rgba(97, 91, 91, 0) 95%); box-shadow: 0px 0 30px 40px rgb(0 0 0 / 30%); }
# #Acc5 .hero>.illu { object-fit: cover; display: flex; width: 100%; height: 100%; z-index: -1;}
# #Acc5 .hero>.c { position: absolute; left: 40px; right: 40px; bottom: 0; margin: auto; max-width: 1280px; height: 296px; display: flex; justify-content: space-between; }
# #Acc5 .hero>.c>div { display: inline-block; vertical-align: top; }
# #Acc5 .hero>.c>.L { width: 290px; margin: -26px 40px 0 0; }
# #Acc5 .hero>.c>.L strong { display: block; font-family: 'SFR-Bold'; font-size: 32px; line-height: 48px; color: #fff; margin: 0 0 16px 0; font-weight:100;}
# #Acc5 .hero>.c>.L p { display: block; font-family: 'SFR-Regular'; font-size: 16px; line-height: 24px; color: #fff; }
# #Acc5 .hero>.c>.L .stars { margin: 16px 0 0 0; }
# #Acc5 .hero>.c>.L .stars>i{ width: 90px; height: 16px; background: url(//static.s-sfr.fr/media/stars-12-grey.svg) no-repeat 0 0; background-size: cover; display: inline-block; vertical-align: middle; }
# #Acc5 .hero>.c>.L .stars>i mark { height: 16px; background: url(//static.s-sfr.fr/media/stars-12-yellow.svg) no-repeat 0 0; background-size: cover; display: block; filter: invert(75%) sepia(86%) saturate(1646%) hue-rotate(26deg) brightness(150%) contrast(107%); }
# #Acc5 .hero>.c>.L .stars>span{ font-size: 12px; color: #fff; line-height: 18px; display: inline-block;vertical-align: middle; margin: 0 0 0 8px; }
# #Acc5 .hero>.c>.M { width: 620px; }
# #Acc5 .hero>.c>.M .illu.mob { display:none }
# #Acc5 .hero>.c>.R { width: 290px; margin: 0 0 118px 0; align-self: flex-end; }
# #Acc5 .hero>.c>.R .sticker { background: var(--clr-yellow); font-family: 'SFR-Bold'; color: var(--clr-black); margin: -20px 0 0 0; font-size: 12px; padding: 0 8px; border-radius: 4px; display: table;}
# #Acc5 .hero>.c>.R .sticker + .price { margin-top: 22px;  }
# #Acc5 .hero>.c>.R .apd { font-size: 14px; line-height: 22px; font-family: 'SFR-Bold'; display: block; color: #fff;  }
# #Acc5 .hero>.c>.R .apd + .price { margin: 0; }
# #Acc5 .hero>.c>.R .apd + .info { margin: 0 0 8px 0; }
# #Acc5 .hero>.c>.R .price { margin: 20px 0 0 0; justify-content: left; }
# #Acc5 .hero>.c>.R .price .L { font-size: 60px; line-height: 48px; color: #fff; }
# #Acc5 .hero>.c>.R .price .R { font-size: 16px; line-height: 24px; color: #fff;}
# #Acc5 .hero>.c>.R .price + a { margin: 16px 0 0 0; }
#
# #Acc5 .hero>.c>.R>.info { font-family: 'SFR-Bold'; color: #fff; font-size: 12px; line-height: 18px; margin: 8px 0;}
# #Acc5 .hero>.c>.R>a { display: table; width: auto; position: static; }
# #Acc5 .hero>.c>.R>a:after { content: ''; position: absolute; left: -640px; right: -640px; top: -164px; width: auto; height: 460px; }
# #Acc5 .hero>.c>.B { display: block; position: absolute; width: fit-content; width:100%; bottom: 80px; height: 18px; }
# #Acc5 .hero>.c>.B>span{ position: absolute; top: 0; right: 0; color: #fff; font-size: 12px; line-height: 18px; display: table; width: calc(100% - 70px);}
# #Acc5 .hero>.c>.B>span:not(.bubble) { text-align: right; }
# #Acc5 .hero>.c>.B>input { display: none; }
# #Acc5 .hero>.c>.B .bubble{ display: none; }
#
# #Acc5 .hero>.c>.B span.das{ left: 0; cursor: pointer; color: #fff; font-size: 12px; line-height: 18px; display: table; position: relative; width:fit-content;}
# #Acc5 .hero>.c>.B span.das:after { content: ''; background-image: url(https://static.s-sfr.fr/assets/pictos/aide_plein_40_blanc.svg); width: 14px; height: 14px; display: block; background-size:contain; background-repeat:no-repeat; position: absolute; top: 1px; left: 28px; }
# #Acc5 .hero>.c>.B span.das:hover + .bubble {display:block; cursor: auto; width: 150px; box-shadow: 0 2px 4px 0 rgb(0 0 0 / 10%); border-radius: 4px; color: #fff; font-family: 'SFR-Regular'; background-color: var(--clr-black); font-size: 10px; padding: 3px; position: absolute; z-index: 9; transition: opacity 0.3s; bottom: 25px; }
# #Acc5 .hero>.c>.B span.das + .bubble:after {content: ""; position: absolute; bottom: -14px; left: 8px; margin-top: -5px; border-width: 7px; border-style: solid; border-color: var(--clr-black) transparent transparent transparent;}
# #Acc5 .hero>.c>.B span.das + .bubble + span { text-align: right; }
#
# #Acc5 .capsules { max-width: 1280px; width: calc(100% - 80px); margin: -70px auto 0 auto; position: relative; display: flex; justify-content: space-around; gap: 0 40px; }
# #Acc5 .cap { display: inline-block; vertical-align: middle; width: 288px; padding: 0 8px 0 0; background: rgba(255, 255, 255, 0.2);max-width: calc(100% / 4 - 15px); width: 288px; font-family: 'SFR-Regular'; color: #fff; border-radius: 8px; font-size: 14px; line-height: 18px; cursor: pointer;  transition: background .3s ease-out; }
# #Acc5 .cap>div { width: 52px; height: 52px; display: inline-block; vertical-align: middle; margin: 0 14px 0 0; }
# #Acc5 .cap>div>.vign { height: 100%; }
# #Acc5 .cap>span { display:inline-block; vertical-align: middle; width: calc(100% - 70px); }
# #Acc5 .cap:hover { background: rgba(24, 24, 24, 0.2);}
# #Acc5 .cap.s { background: rgba(24, 24, 24, 0.2); font-family: 'SFR-Bold';}
# #Acc5 .cap:last-child { margin: 0; }
# #Acc5 .hero[hidden] { background:none; background-image:none; display:none; }
#
# .arrow {padding-right:12px;}
# .arrow:after {content: ''; position: absolute;width: 7px;height: 7px;background-color: transparent;border: 2px solid;right: 0;transform: rotate(45deg);top: 0;bottom: 0;margin: auto;border-left: 0;border-bottom: 0;transition: all .2s cubic-bezier(.4,0,.2,1);}
# .arrow:hover:after {right: -5px;}
# a .arrow {position: relative; display: inline-block; vertical-align: middle; height: 8px; width: 8px; right: -8px;}
# a .arrow:after {content: ''; position: absolute;width: 8px;height: 8px;background-color: transparent;border: 2px solid;right: 0;transform: rotate(45deg);top: 0;bottom: 0;margin: auto;border-left: 0;border-bottom: 0;}
# a:hover .arrow {right: -12px; transition: all .2s cubic-bezier(.4,0,.2,1);}
#
# #Choose { background: #fff; box-shadow: 0px 8px 16px rgba(24, 24, 24, 0.02); border-radius: 12px; max-width: 1280px; margin: 0 auto 40px auto; width: calc(100% - 64px); padding: 24px 24px 90px 24px; display: flex; gap: 22px; flex-wrap: wrap; position: relative; justify-content: space-evenly;  }
# #Choose .c { text-align: center; width: 225px; }
# #Choose .c>img{ height: 64px; margin: 0 0 16px 0; }
# #Choose .c p{ font-family: 'SFR-Bold'; font-size: 14px; margin: 0 0 16px 0; }
# #Choose .c a.link{ text-decoration: none; }
# #Choose .btn4 { width: fit-content; margin: 0 auto; position: absolute; bottom: 24px; left: 0; right: 0; }
#
# #Pilier {text-align: center; padding-bottom: 18px;}
# #Pilier h1 {font-family: 'SFR-Bold'; font-size: 32px; line-height: 36px;margin: 32px auto 40px;}
# #Pilier .z {display: inline-block; vertical-align: middle; width: 720px; text-align: left; margin-bottom: 25px;}
# #Pilier .p {position: relative; display: inline-block; text-align: left; vertical-align: top; margin: 0 1% 0 0;}
# #Pilier .p:last-child {border:none;}
# #Pilier .p .si {display: inline-block; vertical-align: middle; margin: 0px 8px 0 0; }
# #Pilier .p .si + div {display: inline-block; vertical-align: middle;}
# #Pilier .p a {position: relative; display: inline-block; vertical-align: middle; font-family: 'SFR-Bold'; font-size: 14px; text-decoration: none; color: var(--clr-sfr2); line-height: 16px; margin-right: 15px;}
# #Pilier .p a:before {content: ''; position: absolute; width: calc(100% + 92px); height: 70px; top: -50px; left: -63px;}
# #Pilier .p a.m {display: none;}
# #Pilier .p p {margin: 0 0 10px 0; line-height: 18px; width: 190px; font-family: 'SFR-Regular'; font-size: 14px; color: var(--clr-black);}
# #Pilier .m {display: none;}
#
# @keyframes ltr2 {0% {right:-12px;} 50% {right: -20px;} 95% {right: -9px;} 100% {right: -12px;}}
# .tooltip {cursor: pointer; position: absolute; bottom: 45px; right: 20px;z-index:2;}
# #Good { order: 5; position: sticky; padding: 40px 0 0 0; text-align: center; background-color: var(--clr-bg); width: calc(100% - 64px); max-width: 1280px; margin: 0 auto; }
# #Good .wrap {/*width: calc(100% - 64px);max-width: 1280px;*/margin: 24px auto 0 auto;display: grid; grid-template-columns: repeat(3, 1fr); column-gap: 40px; }
# #Good .cbp { background: #fff; padding: 24px; margin: 0 0 40px 0; border-radius: 8px; position: relative; text-align: left; display: grid; grid-row: span 7; grid-template-rows: subgrid; }
# #Good .cbp:hover>img{ transform: scale(1.1); }
# #Good .cbp>img { height: 198px; max-width: 100%; margin: 0 auto 34px auto; display: block; object-fit: contain; transition: 0.5s ease-out transform;}
# #Good .cbp>img + .tooltip + a { margin: 78px 0 8px 0;}
# #Good .cbp>img + a { margin: 78px 0 8px 0;}
# #Good .cbp .tooltip { top: 222px; right: 24px; z-index:2; bottom: auto;}
# #Good .cbp .tooltip .das {position: relative;font-family: 'SFR-Regular';font-size: 12px;line-height:12px; padding: 0 17px 0 0;}
# #Good .cbp .tooltip .das:after {content: "";position: absolute; bottom: -1px; right: 0; width: 15px; height: 15px;background: url(//static.s-sfr.fr/assets/pictos/aide_plein_40_noir.svg);background-repeat:no-repeat;background-size:cover; }
# #Good .cbp .tooltip .tooltiptext { visibility: hidden; cursor: auto; width: 130px; box-shadow: 0 2px 4px 0 rgb(0 0 0 / 10%); border-radius: 4px; color: #fff; font-family: 'SFR-Regular'; background-color: var(--clr-black); font-size: 10px; padding: 8px; position: absolute; z-index: 9; right: -20px; top: auto; bottom: 23px;  transition: opacity 0.3s;}
# #Good .cbp .tooltip .tooltiptext::after {content: ""; position: absolute; bottom: -12px; left: 73%; margin-top: -5px; border-width: 7px; border-style: solid; border-color: var(--clr-black) transparent transparent transparent;}
# #Good .cbp .tooltip:hover .tooltiptext { display: block; visibility: visible; opacity: 1; }
# #Good .cbp .tooltip .das:focus ~ .tooltiptext { display: block; visibility: visible; opacity: 1; }
#
# #Good .cbp .stickers { text-align: left; margin: 0 0 8px 0;}
# #Good .cbp .stickers>span{ border-radius: 4px; padding: 2px 8px; font-size: 14px; font-family: 'SFR-Bold'; line-height: normal; display: inline-block; margin: 0 8px 8px 0;}
# #Good .cbp .stickers>span strong{ font-family: 'SFR-Bold'; }
#
# #Good .cbp>a.t { display:block; font-family: 'SFR-Bold'; font-size: 24px; line-height: normal; margin: 0 0 8px 0; text-decoration: none; color: var(--clr-black);}
# #Good .cbp>a.t:after { content: '';  position: absolute; width: 100%; height: 100%; left: 0; top: 0;}
# #Good .cbp a+p { display:block; font-family: 'SFR-Regular'; font-size: 14px; line-height: normal; margin:0 0 16px 0;}
# #Good .cbp .M { height: 62px; margin: 0 0 16px 0;}
# #Good .cbp .avis { position:relative; margin: 0 0 16px 0; }
# #Good .cbp .avis span { font-size: 12px; font-family: 'SFR-Bold'; display: inline-block; vertical-align: middle; margin: 0 4px 0 0;}
# #Good .cbp .avis>span.nbr { font-size:12px; font-family: 'SFR-Regular'; display:inline-block; z-index: 5; position: absolute; top: 5px; margin: 0 0 0 5px; color:var(--clr-black);}
# #Good .cbp .avis>img{ height: 16px; width: 16px; filter: invert(84%) sepia(19%) saturate(5971%) hue-rotate(0deg) brightness(105%) contrast(103%); display: inline-block; vertical-align: middle; }
# #Good .cbp .avis>svg{ display: inline-block; vertical-align: middle; }
# #Good .cbp .avis>img.emp{ height: 18px; width: 18px; margin: 0 0 0 -1px; }
# #Good .cbp .taddp {display: block; font-size: 14px;}
# #Good .cbp .B { font-size: 14px; }
# #Good .cbp .B .taddp + .price { margin: 8px 0; }
# #Good .cbp .B .price { width: fit-content; margin: 26px 0 8px 0;}
# #Good .cbp span{ display: block;}
# #Good .cbp .B span:last-child{ margin: 0; }
# #Good .cbp .B>span.s1{ margin: 50px 0 0 0; }
# #Good .cbp .B>p{ margin: 0 0 8px 0; display: block; height: 42px;}
# #Good .cbp a.link {text-align: center; width: max-content; text-decoration:none;margin: 24px auto 0 auto;}
#
# @keyframes fadein {from {opacity: 0.5;} to {opacity: 1;}}
#
# #News {position: relative; max-width: 1280px; width:calc(100% - 64px); margin: 40px auto; background-color: var(--clr-bg); text-align: center; /*padding: 40px 0;*/}
# #News h2 {font-family: 'SFR-Bold'; color: var(--clr-black); text-align: left; text-transform: unset; display: block; margin: 0 auto 24px;}
# #News .card { box-shadow: 0 0 24px 4px rgba(0, 0, 0, 0.06); border-radius: 8px; box-sizing: border-box; }
# #News .card a {text-decoration: none;}
# #News .card .T {position: relative; height: 192px; width: 100%; background-size: cover; background-position: center center; border-radius: 8px 8px 0 0; overflow: hidden;}
# #News .card .T span {position: absolute; color: #fff; font-family: 'SFR-Bold'; background-color: var(--clr-black); font-size: 10px; border-radius: 4px; padding: 5px 8px; top: 12px; left: 12px;}
# #News .card .T .illu {width: 100%; border-radius: 8px 8px 0 0;}
# #News .card .T .illu>img {object-fit: cover;}
# #News .card .T .illu.mob { display: none; }
# #News .card .B {height: calc(320px - 192px); width: 100%; padding: 16px 24px; text-align: left; box-sizing: border-box; white-space: normal; background-color:#fff; border-radius: 0 0 8px 8px;}
# #News .card .B .date {font-family: 'SFR-Regular';font-size: 12px;line-height: 16px;color: var(--clr-black);display: block;margin-bottom: 8px;}
# #News .card .B .titre {font-family: 'SFR-Bold';font-size: 16px;line-height: 20px;color: var(--clr-black);margin-bottom: 8px;}
# #News .card .B p {font-family: 'SFR-Regular';font-size: 12px;line-height: 14px;color: var(--clr-black);margin: 8px 0 0;}
# #News>a {position:relative;display: table; margin: 40px auto 0 auto;text-decoration: none;width: fit-content;}
# #News>a:hover { box-shadow: 0 4px 12px rgb(24 24 24 / 32%);}
# #News>a>.arrow { display:none; }
# #News .carousel-preview {display: none;}
# #News #carousel-actu { margin: 0 auto; display: flex; justify-content: center; gap: 40px; }
# #News #carousel-actu > div > div {scroll-snap-type: x mandatory;}
# #News #actu-dots {display: none;}
# body #eTav>ul>li {color: #595959;}
#
# @media all and (max-width: 1100px) {
#     h1 { background: #fff; padding: 16px; margin: 0; width: auto; font-size: 24px; }
#     #Pilier { display: block; background: #fff; overflow:hidden;}
#     #TT { display: flex; order: 7; margin: 16px auto 40px auto; width: calc(100% - 32px); max-width: 1280px; }
#     #Choose { flex-direction: column; order: 7; gap: 40px; width: calc(100% - 32px); margin: 0 auto 24px auto; }
#     #Choose .c { max-width: none; width: auto; }
#     #Choose .c>img { height: 60px; margin: 0 0 8px 0; }
#     #Choose .c p { margin: 0 0 8px 0; }
#
#     #Acc5 { height: 560px; }
#     #Acc5 .hero:before { height: 448px; }
#     #Acc5 .hero>.c { display: block; height: 448px; left: 16px; right: 16px; display: flex; justify-content: space-around; gap: unset; }
#     #Acc5 .hero>.c>.L { width: 100%; display: block; text-align: center; margin: -26px 0 0 0; position: absolute; }
#     #Acc5 .hero>.c>.L strong { margin: 0 0 0 0; }
#     #Acc5 .hero>.c>.L .stars { margin: 8px 0 0 0; }
#     #Acc5 .hero>.c>.M { max-width: none; width: auto; text-align: right; text-align: center; }
#     #Acc5 .hero>.c>.M .illu { display:none }
#     #Acc5 .hero>.c>.M .illu.mob { display:block }
#     #Acc5 .hero>.c>.R { max-width: none; width: auto; margin: 0 0 178px 0; }
#     #Acc5 .hero>.c>.R>a:after { height: 612px; }
#     #Acc5 .hero>.c>.B { bottom: 146px; }
#     #Acc5 .capsules { width: 100%; max-width: 1100px; margin: -136px auto 0 auto; flex-wrap: wrap; flex-direction: row; gap: 16px; justify-content: space-evenly; padding: 0 16px 16px 16px;}
#     #Acc5 .cap { max-width: none; width: calc(50% - 8px); height: 52px; font-size: 12px; line-height: 18px; padding: 0; }
#     #Acc5 .cap>div { margin: 0 8px 0 0; }
#     #Acc5 .cap>span { width: calc(100% - 70px); }
#
#     #Pilier h1 {font-size: 24px;}
#     #Pilier .p {text-align: center; display: block; border-bottom: 1px solid #d8d8d8; padding: 16px 0; border-right: none; margin: 0 32px;}
#     #Pilier .p svg.si {display: none;}
#     #Pilier .p div>p {display: none;}
#     #Pilier .p .si + div {margin-left: 32px;}
#     #Pilier .p .m {position: relative;display: block;text-align: left; margin-right: 2px}
#     #Pilier .p .m svg {display:inline-block;vertical-align: middle;}
#     #Pilier .p .m a{margin-right:0;width: calc(100% - 40px);color: var(--clr-black);}
#     #Pilier .p:last-child { color: var(--clr-sfr2); }
#     #Pilier .p:last-child .m svg{ filter: invert(13%) sepia(79%) saturate(6072%) hue-rotate(348deg) brightness(86%) contrast(98%); }
#     #Pilier .p:last-child .m a{ color: var(--clr-sfr2);}
#     #Pilier .p>div:not(.m) {display: none;}
#     #Pilier .p a:before {content: '';position: absolute;width: 100vw;height: calc(100% + 32px);top: -16px;left: -44px;}
#
#     #Good { width: calc(100% - 32px); }
#     #Good .wrap { grid-template-columns: repeat(2, 1fr); gap: 0 16px; }
#     #Good .cbp { padding: 16px; margin: 0 0 16px 0; }
#     #Good .cbp>img { height: 185px; }
#     #Good .cbp:hover>img{ transform: none; }
#     #Good .cbp .tooltip { top: 205px; }
#     #Good .cbp>a.t { font-size: 16px; line-height: normal;}
#
#     #News {position: relative; padding: 0; width: calc(100% - 32px); }
#     #News h2 {font-size: 24px; line-height: 28px; color: var(--clr-black); margin: 0 0 40px 0;}
#     #News .card { height: 292px; margin: 0 0 16px 0; display:block;vertical-align: top;}
#     #News .card .T {height: 162px;}
#     #News .card .T .illu { display: none; }
#     #News .card .T .illu.mob { display: block; }
#     #News .card .T span {}
#     #News .card .B {height: calc(292px - 162px); box-sizing: border-box;}
#     #News .card .B .titre {font-size: 14px;line-height: 18px;}
#     #News a {margin: 0 auto 24px auto;}
#     #News #carousel-actu { display: block; max-width: 100%; width: 100%; margin: 0; gap: 16px;}
# }
# @media all and (max-width: 768px) {
#     .arrow:after {width:6px;height:6px;}
#     #Acc5 .hero>.c{ gap: 16px; }
#     #Acc5 .hero>.c>.L { margin: -18px 0 0 0; }
#     #Acc5 .hero>.c>.L strong { font-size: 24px; line-height: 36px;  margin: 0;}
#     #Acc5 .hero>.c>.L p { font-size: 14px; line-height: 22px; }
#
#     #Pilier {padding-bottom: 8px;}
#     #Pilier .p {margin:0 16px;}
#     #Pilier h1 {font-size: 20px;margin:24px auto 8px;}
#         #Good .wrap { grid-template-columns: repeat(1, 1fr); width: auto; }
#         #Good .cbp { display: block; width: 100%; min-width: 325px; margin: 0 auto 16px auto; }
#         #Good .cbp a.link { display: block; }
#
#     #News h2 {font-size: 20px;}
# }
#     #IFS {height: 2px; width: 2px; position: fixed; top: 99vh; left: 0;}
#
#
#
#    #MEA1-iphone15-mobile{ background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/desk_brume-violette_bg_acc.webp); background-size: cover; background-position: left;}
#
#     #MEA2-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/desk_famille_canape_bg_acc_v2.webp); background-size: cover; background-position: center top;}
#
#     #MEA3-honormagc6pro-mobile {background: linear-gradient(180deg, #F2F2F2 72.37%, #545454 100%);}
#     #MEA3-honormagc6pro-mobile:before {display: none;}
#     #MEA3-honormagc6pro-mobile.hero>.c>.L p,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R .apd,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R .price .L,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R .price .R,
#     #MEA3-honormagc6pro-mobile.hero>.c>.R>.info,
#     #MEA3-honormagc6pro-mobile.hero>.c>.B span.das,
#     #MEA3-honormagc6pro-mobile.hero>.c>.B>span {color: var(--clr-black);}
#     #MEA3-honormagc6pro-mobile.hero>.c>.L picture img {max-width: 100%; height: auto;}
#     #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.tab {display: none;}
#     #MEA3-honormagc6pro-mobile.hero>.c>.B span.das:after {background-image: url(https://static.s-sfr.fr/assets/pictos/aide_plein_40_noir.svg);}
#
#     #MEA4-TF_Mars_box_high_tech{background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/desk_vague-bleue-neon_bg_acc.webp); background-size: cover; background-position: left;}
#
#     @media all and (max-width: 1100px){
#         #MEA1-iphone15-mobile{ background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_brume-violette_bg_acc.webp); background-position: center;}
#
#         #MEA2-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_famille-canape_bg_acc.webp);}
#         #MEA2-TF-Mars-Fibre-fixe-SCD.hero>.c>.L strong br {display: none;}
#
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.tab {display: block;}
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.mob {display: none;}
#
#         #MEA4-TF_Mars_box_high_tech{background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_vague-bleue-neon_bg_acc.webp); background-position: center;}
#     }
#
#     @media all and (max-width: 768px){
#         #MEA1-iphone15-mobile{ background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/mob_brume-violette_bg_acc.webp);}
#
#         #MEA2-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/mob_famille_canape_bg_acc_v2-min.webp); background-position: right top;}
#         /*
#         #MEA1-TF-Mars-Fibre-fixe-SCD { background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/mob_famille_canape_bg_acc_v2.webp); background-position: right top;}
#         */
#         #MEA3-honormagc6pro-mobile.hero>.c>.L {margin: -98px 0 0 0;}
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.tab {display: none;}
#         #MEA3-honormagc6pro-mobile.hero>.c>.M .illu.mob {display: block;}
#
#         #MEA4-TF_Mars_box_high_tech{background-image: url(https://static.s-sfr.fr/assets/backgrounds/accordeon/tab_vague-bleue-neon_bg_acc.webp);}
#     }
#   </style>
#   <script src="//static.s-sfr.fr/rbhg.js">
#   </script>
#  </head>
#  <body class="Home">
#   <!--prod-->
#   <!--https://www.sfr.fr-->
#   <style>
#    @font-face{font-family:PI;src:url(//static.s-sfr.fr/img/pic.woff)}
# @font-face{font-family:SR;src:url(//static.s-sfr.fr/assets/fonts/Poppins-Regular.woff2)}
# @font-face{font-family:SB;src:url(//static.s-sfr.fr/assets/fonts/Poppins-Bold.woff2)}
# @font-face{font-family:SD;src:url(//static.s-sfr.fr/assets/fonts/Poppins-Black.woff2)}
# html,body{overflow-x:hidden}
# body{margin:0;padding:0}
# body:before{height:0}
# body.Home #eThS{transition:top .3s}
# body.hF:not(.basket-displayed):before{display:block;content:''}
# body.hF:not(.basket-displayed) #eThS{position:fixed;top:0}
# body:not(.Media) #eThS{box-shadow:0 4px 9px 0 #2222}
# body.hM:after,body.hL:after,#eThS.hL:after{content:"";position:fixed;z-index:62000;width:100%;height:100%;top:0;left:0;background:#0003;backdrop-filter:blur(2px)}
# html>body.hL{max-height:100vh;overflow:hidden!important}
#
#
# #eThS,#eThS *,#eThS :before,#eThS :after{display:inline-block;position:static;box-sizing:border-box;font:inherit;color:inherit;background:#0000;margin:0;padding:0;min-width:0;max-width:none;width:auto;height:auto;text-align:inherit;vertical-align:top;box-shadow:none;border:0;border-radius:0;outline:0;user-select:none;-webkit-font-smoothing: antialiased}
# #eThS{position:relative;visibility:visible;z-index:62100;font:0/1.2 SR,Arial;color:#181818;background:#fff;width:100%;word-break:normal;text-align:center}
# #eThS.hL:after{z-index:1}
# #eThS.rs .Z{transition:none}
# #eThS a,#eThS label,#eThS li,#eThS .CN,#eThS .Z>i{text-decoration:none;cursor:pointer}
# #eThS sup{font-size:70%;transform:translateY(-4px)}
# #eThS b{display:inline;font-family:SB,Arial}
# #eThS [data-pi]{font:0/0 Arial}
# #eThS [data-pi]:before{font:1em/1 PI;white-space:pre;content:attr(data-pi)}
# #eThS [data-n]{position:relative}
# #eThS [data-n]:after{position:absolute;left:calc(50% + 12px);top:20%;transform:translateX(-50%);font:10px/1 SR;padding:2px 3px;content:attr(data-n);color:#fff;background:#D90D25;min-width:14px;text-align:center;border-radius:8px}
# #eThS input[id],#eThT .F,#eThT>.EC>label,#eThT>.EC .C,#eThT>.EC .NO,#eThT>div.EC.C.O>*,#eThT>.EC.C .D,nav#eThM>*{display:none}
# #eThS>nav,#eThS>nav>div,nav#eThM .W,#eThM .W a,#eThM>.Z p,#eThS .Z>i,#eThT>.EC.C .C,#eThT>.EC.C.O>.NO{display:block}
# #eThT>.EC.C p.CN{display:inline-block}
# #eThT>.EC.O>.CN{font-size:0}
# #eThT>.EC.O>.CN:after{font-size:12px;content:'Retour'}
# #eThS .W{position:relative;text-align:left}
# #eThS .Z{position:absolute;z-index:5;text-align:center;left:0;top:56px;width:100%;background:#fff;transform-origin:top;transform:scaleY(0);transition:.3s .1s transform}
# #eThS .Z>*{opacity:0;transition:.2s opacity}
# #eThS .RED{color:#D90D25;font-family:SB,Arial}
# #eThT .SFR:before{font-size:56px;color:#fff;background:#e2001a}
# #eThT form{color:#000;background:#f2f2f2;border-radius:8px}
# #eThT input{padding:0 0 0 16px;font:14px/40px SR,Arial;width:calc(100% - 40px)}
# #eThT .OK{height:40px;width:40px;text-align:center}
# #eThT .OK:before{font:22px/40px PI}
# #eThT>.W>p{position:absolute;right:4px}
# #eThT p>*{padding:0 12px}
# #eThT p>[data-pi]:before{font:24px/56px PI}
# #eThT p>[data-ec]:before{font:10px/2 SB,Arial;content:attr(data-ec);color:#D90D25;border:2px solid #D90D25;border-radius:50%;width:24px;display:block;text-align:center;margin:16px 0;text-shadow:none}
# #eThPL:checked~.PL,#eThRE:checked~.RE,#eThEC:checked~.EC{transform:scale(1)}
# #eThPL:checked~.PL>*,#eThRE:checked~.RE>*,#eThEC:checked~.EC>*,#eThMB:checked~#eThT .MB>*{opacity:1;transition:.1s .3s opacity}
# #eThPL:checked~.W [for=eThPL],#eThRE:checked~.W [for=eThRE],#eThT [for=eThEC],#eThMB:checked~#eThT [for=eThMB],#eThT .PT.O{color:#D90D25}
# #eThMB:checked~#eThT [for=eThMB]:before{content:"l"}
# #eThT>.PL>a{margin:8px;padding:20px 8px;width:140px;font:14px/22px SB,Arial;border-radius:8px}
# #eThT>.PL>a:before{display:block;font:32px/1 PI}
# #eThT>.RE{height:auto;text-align:left;padding:72px 16px 16px;font:14px/1.5 SB,Arial;color:#8a8a8a}
# #eThT>.RE>p{display:block;margin:8px 0 0;font:24px/1.5 SB,Arial;cursor:pointer}
# #eThT>.RE>p:hover{background:#eee}
# #eThT>.RE b{padding:0;color:#181818}
# #eThT>.EC{padding:24px;text-align:center}
# #eThT>.EC>*{display:block;font:14px/22px SR,Arial;;margin:0 0 16px}
# #eThT>.EC>a{max-width:352px;margin:0 auto;padding:8px 0}
# #eThT>.EC>.T{font:24px/1.5 SB,Arial}
# #eThT>.EC>.T:before{display:block;font-size:36px}
# #eThT>.EC>.B,#eThT>.EC>.X{text-align:center;max-width:352px;font:14px/16px SB,Arial;padding:12px 24px;margin:16px auto;width:auto;border-radius:8px;transition:box-shadow .3s}
# #eThT>.EC>.B{color:#fff;background:#D90D25;box-shadow:0 4px 8px #9003}
# #eThT>.EC>.B:hover{box-shadow:0 4px 8px #9005}
# #eThT>.EC>.X{background:#0000;color:#181818;border:1px solid #181818}
# #eThT>.EC>.X:hover{box-shadow:0 4px 8px #2226}
# #eThT [for].EC.C:before{margin:8px -8px;width:40px;border-radius:8px;font:14px/36px SB,Arial;border-width:2px}
# #eThT [for].EC.C:after{left:calc(50% + 18px);top:8%}
# #eThT .CN,#eThM .NEW:after{display:inline-block;margin:16px auto 0;padding:0 8px;color:#D90D25;background:#fee;border-radius:4px;font:12px/1.5 SB,Arial}
# #eThT .NO{background:#fcfcfc;border:0 solid #ccc;border-width:1px 0 0;margin:24px 0;max-height:80vh;overflow:auto}
# #eThT .NO>div{display:block}
# #eThT>.MB{height:calc(100vh - 56px)}
# #eThM .NEW:after{content:'Nouveau';white-space:nowrap;margin:3px 0 0 8px}
# #eThM>.Z p{font:24px/1.5 SB,Arial;margin:16px 0}
# #eThM>.Z a{font:14px/22px SR,Arial;margin:0 0 8px}
# #eThM>.Z:after{content:none}
# #eThM .W>div{display:block;margin:0 0 8px}
# #eThT .EC a:before,#eThM .W [data-pi]:before{font:24px/1 PI;margin:0 8px 0 0}
# #eThM .W p[data-pi]:before{font:24px/1.5 PI}
# #eThM .W>.DC{background:#f2f2f2;border-radius:8px}
# #eThM .W>.DC a{margin:0 0 16px}
# #eThM .W>.SEO{width:99%;max-width:none;padding:16px 0}
# #eThM div.SEO>a{display:inline-block;margin:0 12px 8px;padding:0 12px;border:1px solid #a0a0a0;border-radius:12px}
#
# .Media #eThS,.Media #eThS .SFR,.Media #eThS .RED,.Media #eThS [data-ec],.Media #eThS .B,.Media #eThMB:checked~#eThT [for=eThMB],
# .Media #eThPL:checked~.W [for=eThPL],.Media #eThRE:checked~.W [for=eThRE],.Media #eThT [for=eThEC],.Media #eThMB:checked~#eThT [for=eThMB],
# .Media #eThS [data-n]:not(.EC):after,.Media #eThS .NO,.Media #eThT .PT.O{filter:invert(1)}
# .Media #eThS{color:#000;background:#ddd}
# .Media #eThS .CN,.Media #eThS .NEW:after{filter:invert(1);background:#222}
#
# .Media #eThS form{background:#e7e7e7}
#
#
#
#
# @media(max-width:960px){
# body.hL::-webkit-scrollbar{display:none}
# #eThS.hL:after{height:0}
# #eThT .F,#eThM{opacity:0;transition:.2s .3s opacity}
# #eThT .F{display:block;position:absolute;top:-99px}
# #eThT form{opacity:0;width:80px;position:relative;z-index:-1}
# #eThRE:checked~.W form{position:absolute;top:72px;left:16px;z-index:6;width:calc(100% - 32px);opacity:1;transition:.1s .2s opacity}
# #eThMB:checked~#eThT .MB{transform:scale(1)}
# #eThMB:checked~#eThT .F{opacity:1;display:block;position:absolute;z-index:7;text-align:left;width:100vw;padding:4px 16px;right:-4px;font:14px/22px SR,Arial}
# #eThT .F[data-pi]:before{position:relative;font:20px/1.2 PI;margin:0 8px 0 0}
# #eThMB:checked~#eThT .F:nth-child(1){top:340px;font:24px/1.5 SB,Arial}
# #eThT .F:nth-child(1):before{content:none}
# #eThMB:checked~#eThT .F:nth-child(2){top:calc(84vh - 80px)}
# #eThMB:checked~#eThT .F:nth-child(3){top:calc(84vh - 48px)}
# #eThMB:checked~#eThT .F:nth-child(4){top:calc(84vh - 16px)}
# #eThT>.PL>a{max-width:40vw}
# #eThMB:checked~#eThM{opacity:1;position:absolute;top:56px;left:0;width:100%;z-index:6;text-align:left;padding:16px}
# #eThMB:checked~#eThM>a{display:block;font:24px/1.5 SB,Arial;margin:8px 0 0}
# #eThS .Z>i{font:0/1 Arial;text-align:left;display:block;margin:16px 0 0}
# #eThS .Z>i:after{content:'m';font:32px/1 PI}
# #eThM>a{white-space:nowrap}
# #eThM>.Z,#eThT>.PL{transform:scaleX(0);transform-origin:right;right:0;top:0;padding:0 16px;display:block;z-index:8}
# #eThM .Z.O{transform:scale(1)}
# #eThM .Z.O>*{opacity:1}
# #eThM .W{max-height:calc(100vh - 84px);overflow:auto;padding-bottom:80px}
# #eThT>.PL{height:calc(100vh - 56px);top:56px}
# #eThM [data-af]:after{content:attr(data-af);padding-left:6px}
# #eThM .W>.DC{padding:4px 16px;margin:24px 0 16px}
# #eThT>.EC>a{max-width:256px;text-align:left}
# body.hF:before{height:56px}
# }
# @media(min-width:960.1px){
# #eThS.hL:after{position:absolute;height:126px}
# #eThS .W{max-width:1344px;width:100%;margin:0 auto;padding:0 32px}
# #eThS .Z{top:70px}
# #eThT .SFR:before{font-size:70px}
# #eThT form,#eThT .F{display:inline-block}
# #eThT form{width:calc(100% - 680px);margin:15px 40px;transition:all .3s;position:static}
# #eThT form.A{margin:15px calc(50% - 376px);width:520px}
# #eThT p>*{padding:0 16px}
# #eThT .F:not(.X){font:14px/48px SR,Arial;padding-top:4px;border-bottom:4px solid #0000}
# #eThT .F:not(.X):before{content:none}
# #eThT>.W>p{top:7px;right:16px}
# #eThT>.PL{padding:32px 0}
# #eThT>.PL>a:hover{background:#fee;color:#D90D25}
# #eThT [for].EC{margin:0 8px 0 0}
# #eThT [for].EC:before{margin:8px -8px;width:40px;border-radius:8px}
# #eThT [for].EC:not(.C):before{display:block;text-align:center;color:#fff;background:#D90D25;font:24px/40px PI}
# #eThT [for].EC.C:before{font:14px/36px SB,Arial;border-width:2px}
# .Media #eThT>.PL>a:hover{background:#cff;color:#26f2da}
# #eThT>.PL>a.hi{color:#D90D25}
# .Media #eThT>.PL>a.hi{color:#26f2da}
# #eThT p>.RE,#eThT .MB,#eThT form.A+p>.F{display:none}
# #eThT>.EC{text-align:left;top:0;padding-top:44px;left:auto;right:0;width:400px;height:100vh;transform-origin:right;transform:scaleX(0)}
# #eThT>.EC>.T{margin-top:80px}
# #eThT>.EC:after{right:100%;top:0;width:900vw;height:100vh}
# #eThT>.EC>label{display:block;position:absolute;left:24px;top:24px;width:24px;height:24px;background:#181818;color:#fff;border-radius:50%;font-size:0}
# #eThT>.EC>label:before{font:12px/2 PI;padding:0 6px}
# #eThM>a{display:inline-block;font:14px/48px SR,Arial;padding:4px 20px 0;border-bottom:4px solid #0000}
# #eThM>a:hover{border-color:#7777}
# #eThT .hi{color:#D90D25}
# .Media #eThT .hi{color:#26f2da}
# #eThM>a.hi{border-color:#D90D25}
# .Media #eThM>a.hi,.Media #eThN>.W>a.hi{border-color:#26f2da}
# #eThT>.RE{min-height:56px;padding:16px calc(50% - 300px)}
# #eThS .Z>i{display:none}
# #eThM>a+.Z{top:126px;transition:0s box-shadow,.3s .1s transform}
# #eThM>a:hover+div,#eThM>div:hover{box-shadow:0 24px 24px #0002;transform:scale(1);transition:.3s box-shadow,.3s .1s transform}
# #eThM>a:hover+div>*,#eThM>div:hover>*{opacity:1;transition:.1s .3s opacity}
# #eThM .W,#eThM .W>.SEO{text-align:center}
# #eThM .W>div{text-align:left;display:inline-block;padding:8px calc(8% - 64px) 8px 0;max-width:25%}
# #eThM .W>.DC{padding:0 24px 8px;margin:8px 0}
# #eThM .W a{color:#555}
# #eThM .W a:hover{color:#000}
# body.hF:before{height:126px}
#
# }
# @media(min-width:1200px){
# #eThT form{width:332px}
# #eThT .F.X{font:14px/48px SR,Arial;padding-top:4px;border-bottom:4px solid #0000}
# #eThT .F.X:before{content:none}
# }
#   </style>
#   <header id="eThS">
#    <input id="eThMB" type="checkbox"/>
#    <nav id="eThT">
#     <input id="eThPL" type="checkbox"/>
#     <input id="eThRE" type="checkbox"/>
#     <input id="eThEC" type="checkbox"/>
#     <div class="W">
#      <a class="SFR" data-pi="@" href="https://www.sfr.fr/" title="SFR">
#       SFR
#      </a>
#      <form action="https://www.sfr.fr/recherche" autocomplete="off">
#       <input name="q" placeholder="Rechercher un téléphone, un service, ..." type="text"/>
#       <button class="OK" data-pi="G" title="Rechercher" type="submit">
#       </button>
#      </form>
#      <p>
#       <label class="PL F" data-pi="H" for="eThPL" title="Apps &amp; services">
#        Apps &amp; services
#       </label>
#       <a class="F" data-pi="p" href="https://www.sfrbusiness.fr/offres-pro/?utm_source=referrer&amp;utm_medium=sfr.fr&amp;utm_campaign=Pro_header" title="Pro">
#        Pro
#       </a>
#       <a class="F X" data-pi="I" href="https://assistance.sfr.fr/" title="Aide">
#        Aide
#       </a>
#       <a class="F X" data-pi="U" href="https://boutique.sfr.fr/" title="Trouver une boutique">
#        Trouver une boutique
#       </a>
#       <label class="RE" data-pi="G" for="eThRE" title="Recherche">
#        Recherche
#       </label>
#       <a class="PT" data-hi="0" data-pi="D" href="https://www.sfr.fr/#sfrpt" title="Panier">
#        Panier
#       </a>
#       <a data-pi="E" href="https://webmail.sfr.fr/" title="Mail">
#        Mail
#       </a>
#       <label class="EC" data-pi="a" for="eThEC" title="Client">
#        Client
#       </label>
#       <label class="MB" data-pi="B" for="eThMB" title="Menu">
#        Menu
#       </label>
#      </p>
#     </div>
#     <div class="Z PL">
#      <i>
#       Retour
#      </i>
#      <a data-pi="a" href="https://u.sfr.fr/s/accueil?sun_source=header_siteweb" title="SFR &amp; Moi">
#       SFR &amp; Moi
#      </a>
#      <a data-pi="L" href="https://actus.sfr.fr/" title="SFR Actus">
#       SFR Actus
#      </a>
#      <a data-pi="M" href="https://tv.sfr.fr/" title="TV sur PC">
#       TV sur PC
#      </a>
#      <a data-pi="N" href="https://www.sfrcloud.sfr.fr/" title="SFR Cloud">
#       SFR Cloud
#      </a>
#      <a data-hi="home@|home.boutique@" data-pi="O" href="https://boutique.home.sfr.fr/" title="SFR Home">
#       SFR Home
#      </a>
#      <a data-pi="H" href="https://www.sfr.fr/sfr-et-moi/vos-applis-sfr.html" title="Toutes les apps">
#       Toutes les apps
#      </a>
#     </div>
#     <div class="Z RE">
#     </div>
#     <div class="Z EC">
#      <p class="T" data-pi="a">
#       Espace Client
#      </p>
#      <p class="D">
#       Identifiez-vous pour accéder à votre Espace Client
#      </p>
#      <p class="CN C">
#       Centre de notification
#      </p>
#      <a class="B D" href="https://www.sfr.fr/mon-espace-client/" title="Se connecter">
#       Se connecter
#      </a>
#      <a class="B C" href="https://www.sfr.fr/mon-espace-client/" title="Accéder à l'Espace Client">
#       Accéder à l'Espace Client
#      </a>
#      <a class="X C" href="https://www.sfr.fr/auth/realms/sfr/protocol/openid-connect/logout?redirect_uri=https%3A//www.sfr.fr/cas/logout%3Furl%3Dhttps%253A//www.sfr.fr/" title="Se déconnecter">
#       Se déconnecter
#      </a>
#      <a data-pi="Z" href="https://assistance.sfr.fr/actes-urgence.html" title="Accès aux actes d'urgence">
#       Accès aux actes d'urgence
#      </a>
#      <a class="C" data-pi="I" href="https://www.sfr.fr/routage/identifiant" title="Mots de passe et sécurité">
#       Mots de passe et sécurité
#      </a>
#      <a class="C" data-pi="Y" href="https://www.sfr.fr/routage/gestionlignes" title="Rattacher / Retirer mes lignes">
#       Rattacher / Retirer mes lignes
#      </a>
#      <a class="D" data-pi="T" href="https://www.sfr.fr/suivi-commande/" title="Suivi de commande">
#       Suivi de commande
#      </a>
#      <a class="C" data-pi="T" href="https://espace-client.sfr.fr/suivre-ma-commande/authentification" title="Mes commandes">
#       Mes commandes
#      </a>
#      <a data-pi="d" href="https://www.sfr.fr/offre-internet/demenagement" title="Déménagement">
#       Déménagement
#      </a>
#      <div class="NO">
#      </div>
#      <label class="eThX" data-pi="C" title="Fermer">
#       X
#      </label>
#     </div>
#     <div class="Z MB">
#     </div>
#    </nav>
#    <nav id="eThM">
#     <a href="https://www.sfr.fr/offre-internet" title="Box internet">
#      Box internet
#     </a>
#     <div class="Z">
#      <i>
#       Retour
#      </i>
#      <div class="W">
#       <div>
#        <p data-pi="W">
#         Offres
#        </p>
#        <a href="https://www.sfr.fr/offre-internet" title="Box Internet  ">
#         Box Internet
#        </a>
#        <a href="https://www.sfr.fr/offre-internet/internet-partout" title="Internet partout">
#         Internet partout
#        </a>
#        <a href="https://www.sfr.fr/offre-internet/options" title="Options Box">
#         Options Box
#        </a>
#       </div>
#       <div>
#        <p data-pi="X">
#         Equipements
#        </p>
#        <a class="NEW" href="https://www.sfr.fr/offre-internet/box-high-tech" title="Box + High Tech">
#         Box + High Tech
#        </a>
#        <a href="https://www.sfr.fr/box-8/" title="SFR Box 8X">
#         SFR Box 8X
#        </a>
#        <a href="https://www.sfr.fr/offre-internet/box-internet" title="Box et décodeurs">
#         Box et décodeurs
#        </a>
#        <a href="https://www.sfr.fr/options/repeteur-wifi6" title="Répéteur WiFi">
#         Répéteur WiFi
#        </a>
#        <a href="https://www.sfr.fr/accessoires/maison-connectee-et-gaming" title="Accessoires Box">
#         Accessoires Box
#        </a>
#       </div>
#       <div>
#        <p data-pi="c">
#         Avantages SFR
#        </p>
#        <a href="https://www.sfr.fr/carte-couverture-reseau-sfr-fibre-optique/" title="Couverture réseau Internet et fibre">
#         Couverture réseau Internet et fibre
#        </a>
#        <a data-hi="0" href="https://www.sfr.fr/internet-mobile/sfr-family" title="Avantages Box + Mobile">
#         Avantages Box + Mobile
#        </a>
#        <a href="https://www.sfr.fr/offre-internet/frais-resiliation" title="Changer d'opérateur">
#         Changer d'opérateur
#        </a>
#       </div>
#       <div class="DC">
#        <p>
#         Déjà client
#        </p>
#        <a data-pi="W" href="https://www.sfr.fr/mon-espace-client/redirect.html?D=FCHANGE" title="Changer d'offre">
#         Changer d'offre
#        </a>
#        <a data-pi="d" href="https://www.sfr.fr/offre-internet/demenagement" title="Déménagement Internet">
#         Déménagement Internet
#        </a>
#        <a data-hi="0" data-pi="b" href="https://www.sfr.fr/espace-client/options/" title="Gérer vos options Box ">
#         Gérer vos options Box
#        </a>
#       </div>
#       <div class="SEO">
#        <a href="https://www.sfr.fr/offre-internet/box-high-tech#tablette" title="Tablette Samsung Galaxy Tab A9+">
#         Tablette Samsung Galaxy Tab A9+
#        </a>
#        <a href="https://www.sfr.fr/offre-internet/box-high-tech/casque-meta-metaquest3" title="Casque VR Meta Quest 3">
#         Casque VR Meta Quest 3
#        </a>
#        <a href="https://www.sfr.fr/offre-internet/box-high-tech/samsung-tv-cu7105-43" title="Smart TV Samsung">
#         Smart TV Samsung
#        </a>
#        <a href="https://www.sfr.fr/offre-internet/fibre-optique" title="La Fibre de SFR">
#         La Fibre de SFR
#        </a>
#       </div>
#      </div>
#     </div>
#     <a href="https://www.sfr.fr/offre-mobile" title="Forfaits mobile">
#      Forfaits mobile
#     </a>
#     <div class="Z">
#      <i>
#       Retour
#      </i>
#      <div class="W">
#       <div>
#        <p data-pi="i">
#         Offres
#        </p>
#        <a href="https://www.sfr.fr/offre-mobile" title="Forfait mobile 5G / 4G+">
#         Forfait mobile 5G / 4G+
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/decouvrir-la-5g" title="5G de SFR">
#         5G de SFR
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/options" title="Options mobile">
#         Options mobile
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/international" title="International">
#         International
#        </a>
#        <a data-hi="0" href="https://www.sfr.fr/offre-internet/internet-partout" title="Internet partout">
#         Internet partout
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/carte-prepayee" title="Carte prépayée">
#         Carte prépayée
#        </a>
#       </div>
#       <div>
#        <p data-pi="c">
#         Avantages SFR
#        </p>
#        <a href="https://www.sfr.fr/reseau/carte-couverture-reseau-mobile.html" title="Couverture réseau mobile 4G et 5G">
#         Couverture réseau mobile 4G et 5G
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/bonus-smartphone" title="Bonus smartphone">
#         Bonus smartphone
#        </a>
#        <a data-hi="0" href="https://www.sfr.fr/internet-mobile/sfr-family" title="Avantages Box + Mobile">
#         Avantages Box + Mobile
#        </a>
#       </div>
#       <div class="DC">
#        <p>
#         Déjà client
#        </p>
#        <a data-pi="i" href="https://www.sfr.fr/offre-mobile?context=change&amp;parcours=offre" title="Changer d'offre">
#         Changer d'offre
#        </a>
#        <a data-hi="0" data-pi="b" href="https://www.sfr.fr/espace-client/options/" title="Gérer vos options mobile">
#         Gérer vos options mobile
#        </a>
#        <a data-pi="k" href="https://www.sfr.fr/options/multisurf" title="Multisurf : SIM additionnelle">
#         Multisurf : SIM additionnelle
#        </a>
#       </div>
#       <div class="SEO">
#        <a href="https://www.sfr.fr/offre-mobile/forfait-2h-100mo" title="Forfait 2h offert">
#         Forfait 2h offert
#        </a>
#        <a data-hi="0" href="https://www.sfr.fr/offre-mobile/forfait-200go-5g" title="Forfait 200 Go">
#         Forfait 200 Go
#        </a>
#        <a data-hi="0" href="https://www.sfr.fr/espace-client/options/" title="Packs séjours">
#         Packs séjours
#        </a>
#       </div>
#      </div>
#     </div>
#     <a data-af=" &amp; Accessoires" href="https://www.sfr.fr/offre-mobile/telephone-portable" title="Téléphones">
#      Téléphones
#     </a>
#     <div class="Z">
#      <i>
#       Retour
#      </i>
#      <div class="W">
#       <div>
#        <p data-pi="h">
#         Téléphones
#        </p>
#        <a class="Bientôt" href="https://www.sfr.fr/offre-mobile/telephone-portable" title="Tous les Téléphones">
#         Tous les Téléphones
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/univers-apple" title="Apple">
#         Apple
#        </a>
#        <a class="NEW" href="https://www.sfr.fr/offre-mobile/univers-samsung" title="Samsung">
#         Samsung
#        </a>
#        <a class="NEW" href="https://www.sfr.fr/offre-mobile/univers-xiaomi" title="Xiaomi">
#         Xiaomi
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/bons-plans" title="Bons plans mobile">
#         Bons plans mobile
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/telephones/sans-forfait" title="Téléphones sans forfait">
#         Téléphones sans forfait
#        </a>
#        <a href="https://www.sfr.fr/offre-mobile/telephones/reconditionne" title="Téléphones reconditionnés">
#         Téléphones reconditionnés
#        </a>
#       </div>
#       <div>
#        <p data-pi="g">
#         Accessoires
#        </p>
#        <a href="https://www.sfr.fr/accessoires/" title="Tous les accessoires">
#         Tous les accessoires
#        </a>
#        <a href="https://www.sfr.fr/accessoires/montres-et-bracelets-connectes/montres-connectees" title="Montres connectées">
#         Montres connectées
#        </a>
#        <a href="https://www.sfr.fr/accessoires/accessoires-mobiles/coques-et-protections" title="Coques et protections">
#         Coques et protections
#        </a>
# ...
#       <a href="https://www.sfr.fr/offre-mobile/tarifs-conditions" target="_blank" title="https://www.sfr.fr/offre-mobile/tarifs-conditions">
#        https://www.sfr.fr/offre-mobile/tarifs-conditions
#       </a>
#       .
#       <br/>
#       <br/>
#       <strong>
#        RESEAU 5G
#       </strong>
#       : Réseau 5G de SFR, en cours de déploiement, valable sous réserve de couverture avec offre et terminal 5G compatibles. Réseau 5G 3,5 Ghz ou 2100 MHZ disponible selon les communes des agglomérations couvertes. Détails de couverture sur https://www.sfr.fr/couverture . La 5G présente des performances différentes suivant les fréquences utilisées, débit descendant maximum théorique (association des fréquences 4G et 5G dans les zones couvertes) de 2 Gb/s en bande de fréquence 3,5Ghz et de 995 Mb/s en bande de fréquence 2100 Mhz. La 5G est accessible depuis l’étranger avec une offre SFR et un terminal 5G compatibles, dans la limite des zones couvertes par les réseaux 5G des opérateurs étrangers ayant conclu un accord d’itinérance. Les débits 5G à l’étranger dépendent des opérateurs locaux partenaires de SFR.
#       <br/>
#       <br/>
#       <strong>
#        KIT MAIN LIBRE
#       </strong>
#       : L’utilisation d’un kit mains-libres est recommandée.
#       <br/>
#       <br/>
#       <strong>
#        MOBILE DEBLOQUES
#       </strong>
#       : Tous nos mobiles sont désimlockés, que qui signifie qu’ils peuvent être utilisés avec la SIM d’un autre opérateur.
#       <br/>
#       <br/>
#       <strong>
#        DAS
#       </strong>
#       : Le débit d’absorption spécifique (DAS) local quantifie l’exposition de l’utilisateur aux ondes électromagnétiques de l’équipement concerné. Le DAS maximal autorisé est de 2 W/kg pour la tête et le tronc et de 4 W/kg pour les membres. La mesure DAS tronc peut avoir été calculée par rapport à une certaine distance d'un organisme humain simulé. Reportez-vous à la brochure du constructeur.
#       <br/>
#       <br/>
#       <strong>
#        PAIEMENT EN 4 FOIS SANS FRAIS
#       </strong>
#       : Offre soumise à conditions, réservée aux abonnés mobiles SFR, personnes physiques majeures, domiciliés en France métropolitaine ou dans les DOM et titulaires d’une carte bancaire (Mastercard ou VISA) valable au moins 3 mois après la date de conclusion du contrat de paiement échelonné. Facilité de paiement, sans frais, d’une durée inférieure ou égale à 90 jours, en 4 échéances dont la première intervenant obligatoirement au jour de l’achat. Offre valable pour tout achat d’un terminal mobile et d’accessoires mobiles (uniquement avec l’achat d’un mobile) pour un montant total compris entre 50e et 3000€ (frais de port inclus), accompagné de la souscription simultanée d’un forfait mobile SFR avec un engagement 12 ou 24 mois ou dans le cadre d’un renouvellement de mobile (hors mobile et accessoires nus). Sous réserve d’acceptation du dossier par FLOA BANK, Société Anonyme au capital de 41 228 000 euros - Bâtiment G7, 71 Rue Lucien Faure, 33300 Bordeaux, RCS Bordeaux 434 130 423, ORIAS n°07 028 160 (www.orias.fr), Entreprise soumise au contrôle de l’Autorité de Contrôle Prudentiel et de Résolution (ACPR) 4 Place de Budapest, CS 92469, 75430 Paris Cedex 09
#       <br/>
#       https://www.floabank.fr/images/pdf/CB4X/Conditions-Gnrales-Vente-CB3X-CB4X.pdf
#       <br/>
#       <br/>
#       <strong>
#        FACILITE DE PAIEMENT
#       </strong>
#       : Offre réservée aux abonnés SFR (hors client RED by SFR et SFR Business) titulaires d'un forfait mobile SFR éligible. Selon l’offre et l’équipement éligibles choisis, solution de facilité de paiement d’un montant maximum de 192€, permettant de payer mensuellement (3, 5 ou 8€ /mois) une part du prix de l’équipement mobile sur une durée maximale de 24 mois, sans frais. Limité à une seule offre par ligne mobile. En cas de résiliation de la ligne ou de changement d’offre vers une offre inéligible, l’abonné devra régler l’intégralité des mensualités restant dues par anticipation.
#       <br/>
#       <br/>
#       <strong>
#        CREDIT EN 24 FOIS
#       </strong>
#       <span class="Text600">
#        <strong>
#         : Un crédit vous engage et doit être remboursé. Vérifiez vos capacités de remboursement avant de vous engager.
#        </strong>
#       </span>
#       <br/>
#       <br/>
#       <strong>
#        <u>
#         Exemple de financement d'un achat de 801€ avec un forfait SFR Avec un crédit affecté** en 24X
#        </u>
#       </strong>
#       : Paiement comptant de 81€ puis
#       <span class="Text600">
#        <strong>
#         24 mensualités de 30,00€/mois.TAEG fixe  : 0%.
#        </strong>
#       </span>
#       Taux débiteur fixe de 0%.
#       <span class="Text600">
#        <strong>
#         Montant total dû par l'emprunteur  : 720€
#        </strong>
#       </span>
#       (hors assurance facultative). Coût de l'assurance facultative de 1,23 € par mois en plus de la mensualité. Le taux effectif de l'assurance est de 0.17%. Coût du crédit pris en charge par SFR.
#       <br/>
#       <br/>
#       Offre soumise à conditions, réservée aux abonnés mobiles SFR, personnes physiques majeures, domiciliés en France métropolitaine ou dans les DOM. Offre valable pour tout achat d’un terminal mobile dont le financement est supérieur à 200€, accompagné de la souscription simultanée d’un forfait mobile SFR éligible ou dans le cadre d’un renouvellement de mobile (hors achat de terminaux mobiles nus). La dernière mensualité pourra être ajustée à la hausse comme à la baisse dans la limite de 0,50€.
#       <br/>
#       <br/>
#       SFR SA, 16 rue du Général Alain de Boissieu 75015 Paris - RCS paris N°343 059 564, ORIAS n° 12 065 393 (
#       <a href="https://www.orias.fr" target="_blank" title="www.orias.fr">
#        www.orias.fr
#       </a>
#       ) agit en qualité de mandataire non exclusif en opérations de banque et en services de paiement de FLOA et apportant son concours à la réalisation d'opérations de crédit à la consommation sans agir en qualité de Prêteur.
#       <br/>
#       <br/>
#       *Exemple indicatif et sans valeur contractuelle calculé sur la base d’une première échéance 30 jours après la date du financement.
#       <br/>
#       <br/>
#       **Sous réserve d'acceptation du dossier par FLOA, RCS BORDEAUX 434 130 434 - Immeuble G7, 71 Rue Lucien Faure, 33300 BORDEAUX. ORIAS n°07 028 160 (
#       <a href="https://www.orias.fr" target="_blank" title="www.orias.fr">
#        www.orias.fr
#       </a>
#       ). Vous disposez d’un délai légal de rétractation de 14 jours. Conditions en vigueur au 14/11/2023 et susceptibles de variation.
#       <br/>
#       <br/>
#       ***Soit 0,17% du capital emprunté par mois pour un emprunteur de moins de 66 ans pour les garanties Décès, Perte Totale et Irréversible d’Autonomie (PTIA) et Incapacité Temporaire Totale de travail (ITT). Contrat souscrit par FLOA auprès de ACM VIE SA (SA au capital de 778 371 392 €– RCS STRASBOURG 332 377 597 – Siège social : 4 rue Frédéric-Guillaume Raiffeisen - 67000 STRASBOURG Adresse postale : 63 Chemin Antoine Pardon, 69814 TASSIN cedex) et SERENIS ASSURANCES SA (SA au capital de 16 422 000€ – RCS ROMANS 350 838 686 – Siège social : 25 rue du Docteur Henri Abel, 26000 VALENCE - Adresse postale : 63 Chemin Antoine Pardon, 69814 TASSIN cedex), entreprises régies par le Code des Assurances.
#      </div>
#     </details>
#    </section>
#    <script>
#     _stats_pagename="Web/HomePages/Accueil/V6";
# _stats_univers="Home_Bout";
#    </script>
#   </main>
#   <style>
#    @font-face{font-family:ico;src:url(//static.s-sfr.fr/img/ico.woff)}
# #eTfS,#eTfS *{display:block;color:inherit;margin:0;padding:0;width:auto;height:auto;background:#0000;box-sizing:border-box;position:static;box-shadow:none;border:0;border-radius:0;font:inherit}
# #eTfS a{text-decoration:none;cursor:pointer}
# #eTfS input{display:none}
# #eTfS{background:#181818;position:relative;z-index:60000;width:100%;text-align:left}
# #eTfS:before{clear:both;content:" ";display:block}
# #eTfS>div{color:#fff;margin:0 auto;padding:0 16px 16px;text-align:left;line-height:0;position:relative;max-width:1344px}
# #eTfS input+div{border-bottom:1px solid #444;max-height:84px;padding:0 0 8px;overflow:hidden;transition:max-height .3s}
# #eTfS input:checked+div{max-height:400px}
# #eTfS p.T{position:relative;font:24px/1.5 SB,Arial;padding:24px 0}
# #eTfS label{position:absolute;top:0;display:block;cursor:pointer;width:100%;height:100%}
# #eTfS input:checked+div p.T>[for=T0]{z-index:1}
# #eTfS i{width:12px;height:12px;border:0 solid #fff;border-width:0 1px 1px 0;position:absolute;top:30px;right:3px;transform:rotate(45deg);transition:all .3s}
# #eTfS input:checked+div i{transform:rotate(225deg);top:38px}
# #eTfCOL p{font:14px/1.2 SR,Arial;padding:0 0 16px}
# #eTfSOC,#eTfBAS{width:100%;margin:24px 0 0}
# #eTfSOC{position:relative}
# #eTfSOC img{width:64px;height:auto}
# #eTfSOC>p{position:absolute;bottom:0;left:88px;font:16px/1.2 SB,Arial}
# #eTfSOC a{display:inline-block;font-size:0;margin:0 24px 0 0;vertical-align:top}
# #eTfSOC a+a:after{font:24px/1 ico}
# #eTfS [title=Facebook]:after{content:"V"}
# #eTfS [title=Twitter]:after{content:"Q"}
# #eTfS [title=YouTube]:after{content:"W"}
# #eTfBAS a{font:12px/1.5 SR,Arial;display:inline-block;margin:0 24px 8px 0;text-decoration:underline}
#
# @media(min-width:768px){
# #eTfS>div{padding:0 32px 16px;font-size:0}
# #eTfS p.T{font-size:18px}
# #eTfCOL p{font-size:12px}
# #eTfS input+div{display:inline-block;width:23%;margin-left:2.6%;max-height:none;vertical-align:top;border:0}
# #eTfS #T1+div{margin:0}
# #eTfS label{display:none}
# #eTfSOC img{width:80px}
# #eTfSOC>p{left:104px}}
#
# @media(min-width:1200px){
# #eTfCOL{margin-left:200px;padding-top:16px}
# #eTfSOC{position:absolute;top:16px;left:32px;width:144px}
# #eTfSOC>a:first-child{display:block;margin:0 0 24px}
# #eTfSOC>p{position:static;margin:24px 0}
# #eTfBAS{text-align:justify}
# #eTfBAS b{width:99%;height:1px;display:inline-block}}
#   </style>
#   <footer id="eTfS">
#    <div>
#     <nav id="eTfCOL">
#      <input id="T0" name="T" type="radio"/>
#      <input id="T1" name="T" type="radio"/>
#      <div>
#       <p class="T">
#        S'informer
#        <label for="T0">
#        </label>
#        <label for="T1">
#         <i>
#         </i>
#        </label>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/offre-mobile/tarifs-conditions">
#         Tarifs
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/offre-internet/test-eligibilite-adsl-vdsl-fibre">
#         Information sur les débits
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/engagements-rse/environnement/">
#         Engagements RSE
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/reseau/carte-couverture-reseau-mobile.html">
#         Couverture réseau mobile
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/carte-couverture-reseau-sfr-fibre-optique/">
#         Couverture réseau Fibre et THD
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfrbusiness.fr/">
#         Offres Business
#        </a>
#       </p>
#       <p>
#        <a href="https://tv.sfr.fr/guide">
#         Guide TV
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/handicap/">
#         Handicap
#        </a>
#       </p>
#      </div>
#      <input id="T2" name="T" type="radio"/>
#      <div>
#       <p class="T">
#        Aide
#        <label for="T0">
#        </label>
#        <label for="T2">
#         <i>
#         </i>
#        </label>
#       </p>
#       <p>
#        <a href="https://assistance.sfr.fr/tel-mobile/assu-panne-perte-vol/vol-perte-mobile.html">
#         Mobile perdu ou volé ?
#        </a>
#       </p>
#       <p>
#        <a href="https://espace-client.sfr.fr/gestion-securite/mot-de-passe/oublie/identifiant">
#         Mot de passe oublié
#        </a>
#       </p>
#       <p>
#        <a href="https://assistance.sfr.fr/form/incidents/reseau-fixe.html">
#         Incidents fixe
#        </a>
#       </p>
#       <p>
#        <a href="https://assistance.sfr.fr/form/incidents/reseau-mobile.html">
#         Incidents mobile
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/sfr-et-moi/vos-applis-sfr.html">
#         Applications mobile et services SFR
#        </a>
#       </p>
#       <p>
#        <a href="https://la-communaute.sfr.fr">
#         La Communauté SFR
#        </a>
#       </p>
#      </div>
#      <input id="T3" name="T" type="radio"/>
#      <div>
#       <p class="T">
#        Espace Client
#        <label for="T0">
#        </label>
#        <label for="T3">
#         <i>
#         </i>
#        </label>
#       </p>
#       <p>
#        <a href="https://u.sfr.fr/s/accueil?sun_source=footer_siteweb">
#         Appli SFR &amp; Moi
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/suivi-commande/">
#         Suivre ma commande
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/suivi-commande/">
#         Activer ma ligne
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/offre-internet/demenagement">
#         Déménagement
#        </a>
#       </p>
#       <p>
#        <a href="https://espace-client.sfr.fr/odr/offres-remboursement/">
#         Offres de remboursement
#        </a>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/mon-espace-client/redirect.html?D=RESIL">
#         Résilier
#        </a>
#       </p>
#      </div>
#      <input id="T4" name="T" type="radio"/>
#      <div>
#       <p class="T">
#        Contacts
#        <label for="T0">
#        </label>
#        <label for="T4">
#         <i>
#         </i>
#        </label>
#       </p>
#       <p>
#        <a href="https://www.sfr.fr/contacter/">
#         Commander par téléphone
#        </a>
#       </p>
#       <p>
#        <a href="https://assistance.sfr.fr/contacter/">
#         Nous contacter
#        </a>
#       </p>
#       <p>
#        <a href="https://dommages-reseaux.sfr.fr">
#         Signaler un dommage réseau
#        </a>
#       </p>
#      </div>
#     </nav>
#     <nav id="eTfSOC">
#      <a href="https://www.sfr.fr/">
#       <img alt="SFR" src="//static.s-sfr.fr/assets/logos/SFR.svg"/>
#      </a>
#      <a href="https://fr-fr.facebook.com/SFR" title="Facebook">
#       Facebook
#      </a>
#      <a href="https://twitter.com/SFR" title="Twitter">
#       Twitter
#      </a>
#      <a href="https://www.youtube.com/channel/UCmOWXd_I8xsFRViDcQBNolA" title="YouTube">
#       YouTube
#      </a>
#      <p>
#       Suivez-nous sur les réseaux
#      </p>
#     </nav>
#     <nav id="eTfBAS">
#      <a href="https://www.sfr.fr/mentions-legales.html">
#       Informations légales
#      </a>
#      <a href="https://www.sfr.fr/plan-du-site.html">
#       Plan du site
#      </a>
#      <a href="https://assistance.sfr.fr/sfrmail-appli/phishing-spam/proteger-phishing.html#sfrintid=">
#       Phishing
#      </a>
#      <a href="https://www.sfr.fr/politique-cookies.html">
#       Cookies
#      </a>
#      <a href="https://www.sfr.fr/politique-de-protection-des-donnees-personnelles.html">
#       Données personnelles
#      </a>
#      <a href="https://www.sfr.fr/accessibilite/">
#       Accessibilité
#      </a>
#      <a href="https://signalement.fftelecoms.org/">
#       Signaler un contenu illicite
#      </a>
#      <a href="http://alticefrance.com/">
#       Altice France
#      </a>
#      <b>
#      </b>
#     </nav>
#    </div>
#   </footer>
#   <script>
#    !function(W){
# var _=W._eT,F=_('#eTfS'),b=_.nbP,h0=0;
# _('body>footer,footer#footer').af();F.af(2);
#
# if(_.adC)_.JS('//static.s-sfr.fr/export/bloc/django/newsletter.json?callback=_eT.adC');
# if(!_.T(b))_.ti(function(h,m){m='marginTop';h=W.innerHeight-F[0].offsetTop+F.S(m).replace('px','')*1;if(h>h0+2||h<h0-2)F.S(m,(h0=h)>0?h+'px':0)});
# else F._('a[href]').E(function(o,h){h=o.href.replace(/^https:..(cms|www).sfr.fr/,'');
# if(RegExp('^('+b+')').test('@'+h.replace(/#.*/,'')))_(o).cl(function(e,n){if(n=W.newSFRNavigateTo){e.preventDefault();n(h);W.scrollTo(0,0);_('#eThS').C('TV',/^.tv-sfr/.test(h)?0:1)}})});
# }(window)
#   </script>
#   <script src="//static.s-sfr.fr/rbfg.js">
#   </script>
#  </body>
# </html>

# %%
soup.find('p')
# Out:
# <p><label class="PL F" data-pi="H" for="eThPL" title="Apps &amp; services">Apps &amp; services</label><a class="F" data-pi="p" href="https://www.sfrbusiness.fr/offres-pro/?utm_source=referrer&amp;utm_medium=sfr.fr&amp;utm_campaign=Pro_header" title="Pro">Pro</a><a class="F X" data-pi="I" href="https://assistance.sfr.fr/" title="Aide">Aide</a><a class="F X" data-pi="U" href="https://boutique.sfr.fr/" title="Trouver une boutique">Trouver une boutique</a><label class="RE" data-pi="G" for="eThRE" title="Recherche">Recherche</label><a class="PT" data-hi="0" data-pi="D" href="https://www.sfr.fr/#sfrpt" title="Panier">Panier</a><a data-pi="E" href="https://webmail.sfr.fr/" title="Mail">Mail</a><label class="EC" data-pi="a" for="eThEC" title="Client">Client</label><label class="MB" data-pi="B" for="eThMB" title="Menu">Menu</label></p>

# %%
soup.find_all('p')
# Out:
# [<p><label class="PL F" data-pi="H" for="eThPL" title="Apps &amp; services">Apps &amp; services</label><a class="F" data-pi="p" href="https://www.sfrbusiness.fr/offres-pro/?utm_source=referrer&amp;utm_medium=sfr.fr&amp;utm_campaign=Pro_header" title="Pro">Pro</a><a class="F X" data-pi="I" href="https://assistance.sfr.fr/" title="Aide">Aide</a><a class="F X" data-pi="U" href="https://boutique.sfr.fr/" title="Trouver une boutique">Trouver une boutique</a><label class="RE" data-pi="G" for="eThRE" title="Recherche">Recherche</label><a class="PT" data-hi="0" data-pi="D" href="https://www.sfr.fr/#sfrpt" title="Panier">Panier</a><a data-pi="E" href="https://webmail.sfr.fr/" title="Mail">Mail</a><label class="EC" data-pi="a" for="eThEC" title="Client">Client</label><label class="MB" data-pi="B" for="eThMB" title="Menu">Menu</label></p>,
#  <p class="T" data-pi="a">Espace Client</p>,
#  <p class="D">Identifiez-vous pour accéder à votre Espace Client</p>,
#  <p class="CN C">Centre de notification</p>,
#  <p data-pi="W">Offres</p>,
#  <p data-pi="X">Equipements</p>,
#  <p data-pi="c">Avantages SFR</p>,
#  <p>Déjà client</p>,
#  <p data-pi="i">Offres</p>,
#  <p data-pi="c">Avantages SFR</p>,
#  <p>Déjà client</p>,
#  <p data-pi="h">Téléphones</p>,
#  <p data-pi="g">Accessoires</p>,
#  <p data-pi="c">Avantages SFR</p>,
#  <p>Déjà client</p>,
#  <p data-pi="X">Offres</p>,
#  <p data-pi="c">Avantages</p>,
#  <p>Déjà client</p>,
#  <p data-pi="f">Expérience TV</p>,
#  <p data-pi="e">Bouquets TV</p>,
#  <p>Déjà client</p>,
#  <p class="info">+30€/mois pendant 24 mois<br/>avec le forfait 210 Go 5G<br/>engagement 24 mois</p>,
#  <p class="info">engagement 12 mois</p>,
#  <p>jusqu'au 26 mars une tablette offerte*</p>,
#  <p class="info">+8€/mois pendant 24 mois<br/>avec le forfait 210 Go 5G<br/>engagement 24 mois</p>,
#  <p class="info">avec SFR Fibre Premium<br/>engagement 24 mois</p>,
#  <p>La performance <br/>des réseaux SFR</p>,
#  <p>Large choix d'équipements<br/> et contenus au meilleur prix</p>,
#  <p>Regrouper vos abonnements<br/> et faire des économies</p>,
#  <p>570 boutiques proches<br/> de chez vous</p>,
#  <p>Élu Service Client<br/> de l’Année 2024</p>,
#  <p>Un numéro pas comme les autres.</p>,
#  <p>+8€/mois pendant 24 mois<br/>avec le forfait 210 Go 5G</p>,
#  <p>Un grand écran à petit prix.</p>,
#  <p>+8€/mois pendant 24 mois<br/>avec SFR Fibre</p>,
#  <p>Jusqu'au 16 avril, une tablette A9+ offerte.</p>,
#  <p>+8€/mois pendant 24 mois<br/>avec le forfait 210 Go 5G</p>,
#  <p>Une puissance incroyable.</p>,
#  <p>Il vous suivra jour et nuit.</p>,
#  <p>+8€/mois pendant 24 mois<br/>avec le forfait 210 Go 5G</p>,
#  <p>Sans fil et sans égal.</p>,
#  <p>payable en 4 fois</p>,
#  <p>
#              Vous pouvez également réaliser un <a href="https://www.sfr.fr/mire-test-debit/">test de débit</a> avec la <a href="http://mire.ipadsl.net/">mire ADSL</a> pour déterminer la vitesse réelle de votre bande passante, ou obtenir des informations détaillées sur la technologie <a href="https://www.sfr.fr/offre-internet/fibre-optique">fibre optique</a>.
#              <br/><br/>
#              Que vous recherchiez un <a href="https://www.sfr.fr/offre-mobile">forfait mobile</a> adapté à vos usages ou un <a href="https://www.sfr.fr/offre-mobile/international">forfait international</a> power boosté pour les voyageurs, vous trouverez forcément l’abonnement mobile qui vous convient. Des remises spéciales vous font économiser jusqu'à 15€ par mois et par ligne mobile si vous êtes client <a href="https://www.sfr.fr/internet-mobile">Box et Mobile</a> chez SFR. De plus, vous pourrez partager tous vos gigas avec les membres de votre famille grâce à <a href="https://www.sfr.fr/internet-mobile/sfr-family">SFR Family</a>.
#              <br/><br/>
#              SFR vous propose les derniers <a href="https://www.sfr.fr/offre-mobile/telephone-portable">Téléphones</a> pour votre forfait : les fans inconditionnels d’<a href="https://www.sfr.fr/offre-mobile/telephones/apple">iPhone</a> ne pourront pas passer à côté du dernier né de la marque à la pomme : l’<a href="https://www.sfr.fr/apple-iphone15">iPhone 15</a>. Découvrez sans plus attendre toutes les fonctionnalités supplémentaires comme l’intégration de la puce A17 Pro présente sur l’<a href="https://www.sfr.fr/apple-iphone15pro">iPhone 15 Pro</a> et sur l’<a href="https://www.sfr.fr/apple-iphone15promax">iPhone 15 Pro Max</a>, ainsi qu’un revêtement extérieur en titane sur ces deux modèles, pour une robustesse sans égal. Le dernier de la série, mais pas des moindres, est l’<a href="https://www.sfr.fr/apple-iphone15plus">iPhone 15 Plus</a>. Equipé d’un double appareil avancé avec un objectif principal de 48 Mpx et d’une autonomie les plus élevés de la marque Apple, comment résister ?
#  Chez SFR, profitez encore de la gamme antérieure et (re)découvrez l'<a href="https://www.sfr.fr/apple-iphone14">iPhone 14</a>, l'<a href="https://www.sfr.fr/apple-iphone14plus">iPhone 14 Plus</a>, l'<a href="https://www.sfr.fr/apple-iphone14pro">iPhone 14 Pro</a> et l'<a href="https://www.sfr.fr/apple-iphone14promax">iPhone 14 Pro Max</a>.
#              <br/><br/>
#              Parmi les meilleurs smartphones Android, découvrez toutes les nouveautés de la marque <a href="/offre-mobile/telephones/samsung">Samsung</a>. Notamment avec le dernier venu : le <a href="/samsung-galaxys24">Samsung Galaxy S24</a>. Ce smartphone est un concentré des dernières innovations de la marque, avec un design résolument moderne. La gamme se complète avec le <a href="/samsung-galaxys24ultra">Galaxy S24 Ultra</a>, qui se place en haut de l’affiche dans les smartphones premium, et avec le <a href="/samsung-galaxys24plus">Samsung S24+</a>, qui éblouit par son design, sa puissance et sa polyvalence photographique. (Re)découvrez également le <a href="/samsung-galaxys23fe">Samsung Galaxy S23 FE</a> qui offre des performances puissantes pour un prix réellement abordables. N’oublions pas que la marque sud-coréenne a marqué les esprits, avec les iconiques et fabuleux smartphones pliables : le <a href="/samsung-galaxyzflip5">Galaxy Z Flip5</a> et le <a href="/samsung-galaxyzfold5">Galaxy Z Fold5</a>.
#              <br/><br/>
#  La marque <a href="/offre-mobile/telephones/xiaomi">Xiaomi</a> propose également des smartphones très performants, notamment la toute dernière gamme qui comporte le <a href="/xiaomi-redminote13">Xiaomi Redmi Note 13</a>, le <a href="/xiaomi-redminote135g">Redmi Note 13 5G</a>, le <a href="/xiaomi-redminote13pro5g">Redmi Note 13 Pro 5G</a> et le <a href="/xiaomi-redminote13proplus5g">Xiaomi Redmi Note 13 Pro+ 5G</a>. Dans les nouveautés 2024, découvrez également le <a href="/xiaomi-redmi13c">Xiaomi Redmi 13C</a>, qui pour un téléphone d’entrée de gamme offre des fonctionnalités performantes. D’autres mobiles sortis en 2023 valent le détour également, comme le <a href="/xiaomi-13tconuavecleica">Xiaomi 13T</a> et le <a href="/xiaomi-13tproconuavecleica">Xiaomi 13T Pro</a>, conçu avec Leica, pour vous offrir une expérience photographique exceptionnelle, mais également le <a href="/xiaomi-13">Xiaomi 13</a> et le <a href="/xiaomi-redmia2">Redmi A2</a>.
#              <br/><br/>
#  Pour changer de téléphone à prix vraiment malin, profitez de la <a href="https://www.sfr.fr/offre-mobile/reprise-mobile">reprise mobile</a>, et bénéficiez d’un Bonus reprise jusqu’à 200€ sur les téléphones éligibles. Vous pouvez aussi commander votre <a href="https://www.sfr.fr/offre-mobile/telephones/sans-forfait">téléphone sans forfait</a> et débloqué tout opérateur. Retrouvez l'ensemble de notre catalogue mobile à l'achat aux meilleurs prix, avec en prime les <a href="https://www.sfr.fr/offre-mobile/telephones/reconditionne">téléphones reconditionnés</a> (<a href="https://www.sfr.fr/offre-mobile/reconditionne">tout savoir sur les téléphones reconditionnés</a> chez SFR), et les <a href="https://www.sfr.fr/offre-mobile/telephones/5g">smartphones 5G</a>. Enfin, retrouvez tous les <a href="https://www.sfr.fr/assistance/telephone-mobile/mode-emploi/">modes d'emploi de vos téléphones</a> préférés.
#              <br/><br/>
#              Pour être à la pointe de la technologie, n’hésitez pas à allier des accessoires mobiles à votre smartphone. Que serait l’iPhone 13 sans les <a href="https://www.sfr.fr/accessoires/details/apple-airpods-boitier-recharge">Airpods</a> ou les smartphones Samsung <a href="https://www.sfr.fr/accessoires/details/samsung-galaxy-buds-fe-blanc">Galaxy Buds FE</a> ? Découvrez tous les <a href="https://www.sfr.fr/accessoires/casque-ecouteurs-et-enceintes/casques-et-ecouteurs">écouteurs</a> et casques audio, ainsi que les <a href="https://www.sfr.fr/accessoires/casque-ecouteurs-et-enceintes/enceintes">enceintes Bluetooth</a> en vente chez SFR. Aujourd’hui, ne passez pas à côté des <a href="https://www.sfr.fr/accessoires/montres-et-bracelets-connectes/montres-connectees">montres connectées</a>, des indispensables, comme les <a href="https://www.sfr.fr/accessoires/apple-watch/">Apple Watch</a> ou la <a href="https://www.sfr.fr/accessoires/details/samsung-galaxy-watch6-classic-sfr">Samsung Galaxy Watch 6</a>. Et pour personnaliser votre mobile comme vous le souhaitez, n’oubliez pas de prendre une <a href="https://www.sfr.fr/accessoires/accessoires-mobiles/coques-et-protections">coque de téléphone</a> ou une protection.
#              <br/><br/>
#              Être client SFR c'est bénéficier d'une excellente couverture <a href="https://www.sfr.fr/offre-mobile/couverture-reseau-mobile">réseau mobile</a> couvrant près de 99% de la population en 4G / 4G+, et du réseau <a href="https://www.sfr.fr/offre-mobile/decouvrir-la-5g">5G</a> dont SFR continue le déploiement sur le territoire français (voir aussi : <a href="https://www.sfr.fr/reseau-5g/">qu’est-ce que la 5G ?</a>).
#              <br/><br/>
#  <strong>Sport, Ciné, Séries</strong>
#  <br/>
#              Vos programmes préférés sont disponibles dans l'<a href="https://www.sfr.fr/tv-sfr">offre TV</a> de SFR : naviguez dans notre <a href="https://www.sfr.fr/tv-sfr/toutes-les-chaines">catalogue de chaînes</a> parmi 5 thématiques. Zappez entre les <a href="https://www.sfr.fr/tv-sfr/bouquets-sport">rencontres sportives</a> et les <a href="https://www.sfr.fr/tv-sfr/bouquets-cinema-et-series">séries TV</a>. Evadez-vous avec National Geographic et les émissions de voyage ou détendez-vous en famille avec les <a href="https://www.sfr.fr/tv-sfr/bouquets-jeunesse">chaînes Jeunesse</a> et <a href="https://www.sfr.fr/tv-sfr/disneyplus-bouquet-famille">Disney+</a>. Regardez les meilleures séries sur <a href="https://www.sfr.fr/tv-sfr/netflix-sfr">Netflix</a>, <a href="https://www.sfr.fr/tv-sfr/ocs-sfr">OCS</a>, <a href="https://www.sfr.fr/tv-sfr/amazon-prime">Amazon Prime Video</a>, ou <a href="https://www.sfr.fr/tv-sfr/canalplus24-sfr">Canal+</a> et vivez le meilleur du sport avec l’abonnement <a href="https://www.sfr.fr/tv-sfr/plus-sport-eng">RMC Sport + beIN Sport</a> l’offre couplée à prix réduit.
#              <br/><br/>
#              Avec <a href="https://www.sfr.fr/options/cafeyn">Cafeyn</a>, retrouvez les grands titres de la presse française en illimité, une expérience de lecture unique disponible sur tous vos écrans. Enfin, avec SFR Actus retrouvez toute <a href="https://actus.sfr.fr/cine-series/">l'actualité ciné-séries</a>, sport, divertissement, <a href="https://actus.sfr.fr/tech/">les actus sur les dernières technologies</a>, ainsi qu'une rubrique <a href="https://actus.sfr.fr/guide-et-comparatif/">guide</a> avec des comparatifs smartphone et plus encore.
#          </p>,
#  <p class="T">S'informer<label for="T0"></label><label for="T1"><i></i></label></p>,
#  <p><a href="https://www.sfr.fr/offre-mobile/tarifs-conditions">Tarifs</a></p>,
#  <p><a href="https://www.sfr.fr/offre-internet/test-eligibilite-adsl-vdsl-fibre">Information sur les débits</a></p>,
#  <p><a href="https://www.sfr.fr/engagements-rse/environnement/">Engagements RSE</a></p>,
#  <p><a href="https://www.sfr.fr/reseau/carte-couverture-reseau-mobile.html">Couverture réseau mobile</a></p>,
#  <p><a href="https://www.sfr.fr/carte-couverture-reseau-sfr-fibre-optique/">Couverture réseau Fibre et THD</a></p>,
#  <p><a href="https://www.sfrbusiness.fr/">Offres Business</a></p>,
#  <p><a href="https://tv.sfr.fr/guide">Guide TV</a></p>,
#  <p><a href="https://www.sfr.fr/handicap/">Handicap</a></p>,
#  <p class="T">Aide<label for="T0"></label><label for="T2"><i></i></label></p>,
#  <p><a href="https://assistance.sfr.fr/tel-mobile/assu-panne-perte-vol/vol-perte-mobile.html">Mobile perdu ou volé ?</a></p>,
#  <p><a href="https://espace-client.sfr.fr/gestion-securite/mot-de-passe/oublie/identifiant">Mot de passe oublié</a></p>,
#  <p><a href="https://assistance.sfr.fr/form/incidents/reseau-fixe.html">Incidents fixe</a></p>,
#  <p><a href="https://assistance.sfr.fr/form/incidents/reseau-mobile.html">Incidents mobile</a></p>,
#  <p><a href="https://www.sfr.fr/sfr-et-moi/vos-applis-sfr.html">Applications mobile et services SFR</a></p>,
#  <p><a href="https://la-communaute.sfr.fr">La Communauté SFR</a></p>,
#  <p class="T">Espace Client<label for="T0"></label><label for="T3"><i></i></label></p>,
#  <p><a href="https://u.sfr.fr/s/accueil?sun_source=footer_siteweb">Appli SFR &amp; Moi</a></p>,
#  <p><a href="https://www.sfr.fr/suivi-commande/">Suivre ma commande</a></p>,
#  <p><a href="https://www.sfr.fr/suivi-commande/">Activer ma ligne</a></p>,
#  <p><a href="https://www.sfr.fr/offre-internet/demenagement">Déménagement</a></p>,
#  <p><a href="https://espace-client.sfr.fr/odr/offres-remboursement/">Offres de remboursement</a></p>,
#  <p><a href="https://www.sfr.fr/mon-espace-client/redirect.html?D=RESIL">Résilier</a></p>,
#  <p class="T">Contacts<label for="T0"></label><label for="T4"><i></i></label></p>,
#  <p><a href="https://www.sfr.fr/contacter/">Commander par téléphone</a></p>,
#  <p><a href="https://assistance.sfr.fr/contacter/">Nous contacter</a></p>,
#  <p><a href="https://dommages-reseaux.sfr.fr">Signaler un dommage réseau</a></p>,
#  <p>Suivez-nous sur les réseaux </p>]

# %%
soup.find('p').get_text()
# Out:
# 'Apps & servicesProAideTrouver une boutiqueRecherchePanierMailClientMenu'

# %%
soup.find('p').get_text().strip()
# Out:
# 'Apps & servicesProAideTrouver une boutiqueRecherchePanierMailClientMenu'

# %%
soup.find_all('p')[0].get_text()
# Out:
# 'Apps & servicesProAideTrouver une boutiqueRecherchePanierMailClientMenu'

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/ids_and_classes.html")
soup = BeautifulSoup(page.content)
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>,
#  <p class="inner-text">
#                  Second paragraph.
#              </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %%
soup.find_all('p', {"class":"outer-text"})[0].get_text().strip()
# Out:
# 'First outer paragraph.'

# %%
soup.find_all('p', {"class":"outer-text", "id":"second"})[0].get_text().strip()
# Out:
# 'First outer paragraph.'

# %%
soup.find(id="first")
# Out:
# <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>

# %%
wikipedia_DS_url = "https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es"
wiki_raw = requests.get(wikipedia_DS_url)
soup = BeautifulSoup(wiki_raw.content)
str(soup)[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="fr">\n<head>\n<meta charset="utf-8"/>\n<title>Science des données — Wikipédia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled '

# %%
main_soup = soup.find("main")
str(main_soup)[:1000]
# Out:
# '<main class="mw-body" id="content" role="main">\n<header class="mw-body-header vector-page-titlebar">\n<nav aria-label="Sommaire" class="vector-toc-landmark" role="navigation">\n<div class="vector-dropdown vector-page-titlebar-toc vector-button-flush-left" id="vector-page-titlebar-toc">\n<input aria-haspopup="true" aria-label="Basculer la table des matières" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox"/>\n<label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label"><span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet"></span>\n<span class="vector-dropdown-label-text">Basculer la table des matières</span>\n</label>\n<div class="vector-dropdown-content">\n<div class="vector-unpi'

# %%
links = main_soup.find_all("a")

# %%
links = main_soup.find_all("a", href=True, title=True)
links[:10]
# Out:
# [<a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA" hreflang="ar" lang="ar" title="علم البيانات – arabe"><span>العربية</span></a>,
#  <a class="interlanguage-link-target" href="https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi" hreflang="az" lang="az" title="Verilənlər elmi – azerbaïdjanais"><span>Azərbaycanca</span></a>,
#  <a class="interlanguage-link-target" href="https://bg.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%B7%D0%B0_%D0%B4%D0%B0%D0%BD%D0%BD%D0%B8%D1%82%D0%B5" hreflang="bg" lang="bg" title="Наука за данните – bulgare"><span>Български</span></a>,
#  <a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%AA%E0%A6%BE%E0%A6%A4%E0%A7%8D%E0%A6%A4_%E0%A6%AC%E0%A6%BF%E0%A6%9C%E0%A7%8D%E0%A6%9E%E0%A6%BE%E0%A6%A8" hreflang="bn" lang="bn" title="উপাত্ত বিজ্ঞান – bengali"><span>বাংলা</span></a>,
#  <a class="interlanguage-link-target" href="https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades" hreflang="ca" lang="ca" title="Ciència de les dades – catalan"><span>Català</span></a>,
#  <a class="interlanguage-link-target" href="https://cs.wikipedia.org/wiki/Data_science" hreflang="cs" lang="cs" title="Data science – tchèque"><span>Čeština</span></a>,
#  <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Data_Science" hreflang="de" lang="de" title="Data Science – allemand"><span>Deutsch</span></a>,
#  <a class="interlanguage-link-target" href="https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD" hreflang="el" lang="el" title="Επιστήμη δεδομένων – grec"><span>Ελληνικά</span></a>,
#  <a class="interlanguage-link-target" href="https://en.wikipedia.org/wiki/Data_science" hreflang="en" lang="en" title="Data science – anglais"><span>English</span></a>,
#  <a class="interlanguage-link-target" href="https://eo.wikipedia.org/wiki/Datum-scienco" hreflang="eo" lang="eo" title="Datum-scienco – espéranto"><span>Esperanto</span></a>]

# %%
'Bonjour'.startswith("a")
# Out:
# False

# %%
links = main_soup.find_all("a", href=lambda link: link and link.startswith("/wiki/"), title=True)

# %%
print(links[:5])
# Out:
# [<a accesskey="c" href="/wiki/Science_des_donn%C3%A9es" title="Voir le contenu de la page [c]"><span>Article</span></a>, <a accesskey="t" href="/wiki/Discussion:Science_des_donn%C3%A9es" rel="discussion" title="Discussion au sujet de cette page de contenu [t]"><span>Discussion</span></a>, <a accesskey="j" href="/wiki/Sp%C3%A9cial:Pages_li%C3%A9es/Science_des_donn%C3%A9es" title="Liste des pages liées qui pointent sur celle-ci [j]"><span>Pages liées</span></a>, <a accesskey="k" href="/wiki/Sp%C3%A9cial:Suivi_des_liens/Science_des_donn%C3%A9es" rel="nofollow" title="Liste des modifications récentes des pages appelées par celle-ci [k]"><span>Suivi des pages liées</span></a>, <a accesskey="u" href="/wiki/Aide:Importer_un_fichier" title="Téléverser des fichiers [u]"><span>Téléverser un fichier</span></a>]

# %%
liens = []
for l in links:
    liens.append(l['href'])

# %%
liens[:5]
# Out:
# ['/wiki/Science_des_donn%C3%A9es',
#  '/wiki/Discussion:Science_des_donn%C3%A9es',
#  '/wiki/Sp%C3%A9cial:Pages_li%C3%A9es/Science_des_donn%C3%A9es',
#  '/wiki/Sp%C3%A9cial:Suivi_des_liens/Science_des_donn%C3%A9es',
#  '/wiki/Aide:Importer_un_fichier']

# %%
from urllib.parse import unquote


decoded_urls = [unquote(url) for url in liens]

for i,url in enumerate(decoded_urls):
    print(url)
    if i==4: break
# Out:
# /wiki/Science_des_données
# /wiki/Discussion:Science_des_données
# /wiki/Spécial:Pages_liées/Science_des_données
# /wiki/Spécial:Suivi_des_liens/Science_des_données
# /wiki/Aide:Importer_un_fichier

# %%
links[0]['href']
# Out:
# '/wiki/Science_des_donn%C3%A9es'

# %%
list_of_article_links = [ link["href"] for link in links ]
list_of_article_links = [unquote(url) for url in list_of_article_links]; list_of_article_links[:10]
# Out:
# ['/wiki/Science_des_données',
#  '/wiki/Discussion:Science_des_données',
#  '/wiki/Spécial:Pages_liées/Science_des_données',
#  '/wiki/Spécial:Suivi_des_liens/Science_des_données',
#  '/wiki/Aide:Importer_un_fichier',
#  '/wiki/Spécial:Pages_spéciales',
#  '/wiki/Science',
#  '/wiki/Architecte_de_données',
#  '/wiki/Donnée',
#  '/wiki/Modèle:Infobox_Discipline']

# %%
example_url = list_of_article_links[0]
requests.get(example_url).content
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[38], line 2
#       1 example_url = list_of_article_links[0]
# ----> 2 requests.get(example_url).content
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:439, in PreparedRequest.prepare_url(self, url, params)
#     436     raise InvalidURL(*e.args)
#     438 if not scheme:
# --> 439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
#     445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL '/wiki/Science_des_données': No scheme supplied. Perhaps you meant https:///wiki/Science_des_données?

# %%
prefix = "https://fr.wikipedia.org"
prefix + list_of_article_links[0]
# Out:
# 'https://fr.wikipedia.org/wiki/Science_des_données'

# %%
first_article_content = requests.get(prefix + list_of_article_links[0]).content
first_article_content[:1000]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" lang="fr" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Science des donn\xc3\xa9es \xe2\x80\x94 Wikip\xc3\xa9dia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabl'

# %%
list_article_links_complete = [prefix + extension for extension in list_of_article_links]
list_article_links_complete[:10]
# Out:
# ['https://fr.wikipedia.org/wiki/Science_des_données',
#  'https://fr.wikipedia.org/wiki/Discussion:Science_des_données',
#  'https://fr.wikipedia.org/wiki/Spécial:Pages_liées/Science_des_données',
#  'https://fr.wikipedia.org/wiki/Spécial:Suivi_des_liens/Science_des_données',
#  'https://fr.wikipedia.org/wiki/Aide:Importer_un_fichier',
#  'https://fr.wikipedia.org/wiki/Spécial:Pages_spéciales',
#  'https://fr.wikipedia.org/wiki/Science',
#  'https://fr.wikipedia.org/wiki/Architecte_de_données',
#  'https://fr.wikipedia.org/wiki/Donnée',
#  'https://fr.wikipedia.org/wiki/Modèle:Infobox_Discipline']

# %%
import requests
import pandas as pd

# %%
list_article_links_complete = [prefix + extension for extension in list_of_article_links]
list_article_links_complete[:10]
# Out:
# ['https://fr.wikipedia.org/wiki/Science_des_données',
#  'https://fr.wikipedia.org/wiki/Discussion:Science_des_données',
#  'https://fr.wikipedia.org/wiki/Spécial:Pages_liées/Science_des_données',
#  'https://fr.wikipedia.org/wiki/Spécial:Suivi_des_liens/Science_des_données',
#  'https://fr.wikipedia.org/wiki/Aide:Importer_un_fichier',
#  'https://fr.wikipedia.org/wiki/Spécial:Pages_spéciales',
#  'https://fr.wikipedia.org/wiki/Science',
#  'https://fr.wikipedia.org/wiki/Architecte_de_données',
#  'https://fr.wikipedia.org/wiki/Donnée',
#  'https://fr.wikipedia.org/wiki/Modèle:Infobox_Discipline']

# %%
pd.DataFrame(list_article_links_complete, columns=['liens'])
# Out:
#                                                  liens
# 0    https://fr.wikipedia.org/wiki/Science_des_données
# 1    https://fr.wikipedia.org/wiki/Discussion:Scien...
# 2    https://fr.wikipedia.org/wiki/Spécial:Pages_li...
# 3    https://fr.wikipedia.org/wiki/Spécial:Suivi_de...
# 4    https://fr.wikipedia.org/wiki/Aide:Importer_un...
# ..                                                 ...
# 328  https://fr.wikipedia.org/wiki/Catégorie:Portai...
# 329  https://fr.wikipedia.org/wiki/Catégorie:Portai...
# 330  https://fr.wikipedia.org/wiki/Catégorie:Projet...
# 331  https://fr.wikipedia.org/wiki/Catégorie:Portai...
# 332  https://fr.wikipedia.org/wiki/Catégorie:Portai...
#
# [333 rows x 1 columns]

# %%
from tqdm.notebook import tqdm
import numpy as np

# %%
articles_number_notes = []

for article_link in tqdm(list_article_links_complete[:50]): # intégrer tdqm permet d'afficher une barre de progression de la boucle

    # constitution de notre soup de façon classique
    first_article_content = requests.get(article_link).content
    first_article_soup = BeautifulSoup(first_article_content, 'html.parser')

    # Certains articles n'auront ni notes ni références, ils donneront une erreur
    # Ces erreurs seront gérés par la commande except
    try:

        # On parcourt l'arbre pour trouver les éléments dans la liste référence
        notes_et_references = (first_article_soup
                               .find('main')
                               .find("ol", {"class": "references"})
                               .find_all("li")
                              )
        # on stocke dans une liste le nombre de références
        number_of_notes = len(notes_et_references)
        articles_number_notes.append(number_of_notes)

    except AttributeError:
        print("No note or reference in article", article_link)
        articles_number_notes.append(0)   # Il n'y a pas de notes donc on ajoute 0 à la liste.

print("\nMedian number of notes per article is", np.median(articles_number_notes))
print("Mean number of notes per article is", np.mean(articles_number_notes))
print("Stdev of number of notes per article is", np.std(articles_number_notes))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# No note or reference in article https://fr.wikipedia.org/wiki/Discussion:Science_des_données
# No note or reference in article https://fr.wikipedia.org/wiki/Spécial:Pages_liées/Science_des_données
# No note or reference in article https://fr.wikipedia.org/wiki/Spécial:Suivi_des_liens/Science_des_données
# No note or reference in article https://fr.wikipedia.org/wiki/Aide:Importer_un_fichier
# No note or reference in article https://fr.wikipedia.org/wiki/Spécial:Pages_spéciales
# No note or reference in article https://fr.wikipedia.org/wiki/Architecte_de_données
# No note or reference in article https://fr.wikipedia.org/wiki/Modèle:Infobox_Discipline
# No note or reference in article https://fr.wikipedia.org/wiki/Tableau_de_bord_(informatique)
# No note or reference in article https://fr.wikipedia.org/wiki/Aide:Recyclage
# No note or reference in article https://fr.wikipedia.org/wiki/Spécial:EditPage/Science_des_données
# No note or reference in article https://fr.wikipedia.org/wiki/Discussion:Science_des_données
# No note or reference in article https://fr.wikipedia.org/wiki/Aide:Recyclage
# No note or reference in article https://fr.wikipedia.org/wiki/Spécial:EditPage/Science_des_données
# No note or reference in article https://fr.wikipedia.org/wiki/Discussion:Science_des_données
#
# Median number of notes per article is 9.0
# Mean number of notes per article is 23.04
# Stdev of number of notes per article is 36.16902542231405

# %%
import matplotlib.pyplot as plt

plt.boxplot(articles_number_notes, patch_artist=True);

# %%
import seaborn as sns
plt.figure(figsize=(4,5))
sns.violinplot(data=articles_number_notes);
